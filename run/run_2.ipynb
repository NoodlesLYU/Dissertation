# %%
import os
import time
import pandas as pd
import numpy as np
from geojson import dump
import geopandas as gpd
from shapely.geometry import Point
from shapely.ops import nearest_points
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar
import networkx as nx
import os
import osmnx as ox
import pickle
import struct
import csv

# %%
def loadQUANTMatrix(filename):
    with open(filename,'rb') as f:
        (m,) = struct.unpack('i', f.read(4))
        (n,) = struct.unpack('i', f.read(4))
        print("loadQUANTMatrix::m=",m,"n=",n)
        matrix = np.arange(m*n,dtype=np.float64).reshape(m, n) #and hopefully m===n, but I'm not relying on it
        for i in range(0,m):
            data = struct.unpack('{0}f'.format(n), f.read(4*n)) #read a row back from the stream - data=list of floats
            for j in range(0,n):
                matrix[i,j] = data[j]
    return matrix

def saveMatrix(matrix,filename):
    with open(filename,'wb') as f:
        pickle.dump(matrix,f)

class QUANTLHModel:
    """
    constructor
    @param n number of residential zones (MSOA)
    @param m number of school point zones
    """

    def __init__(self, m, n):
        # constructor
        self.m = m
        self.n = n
        self.Ei = np.zeros(m)
        self.Aj = np.zeros(n)
        self.cij_0 = np.zeros(1)  # costs matrix - set to something BIG later
        self.cij_1 = np.zeros(1)  # costs matrix - set to something BIG later
        self.cij_2 = np.zeros(1)  # costs matrix - set to something BIG later
        self.SObs_0 = np.zeros(1)
        self.SObs_1 = np.zeros(1)
        self.SObs_2 = np.zeros(1)

    ################################################################################

    """
    setPopulationVectorEi
    Overload of setPopulationEi to set Ei directly from a vector, rather than a Pandas dataframe.
    """
    def setPopulationVectorEi(self, Ei):
        self.Ei = Ei
        assert len(self.Ei) == self.m, "FATAL: setPopulationEi length Ei=" + str(
            len(self.Ei)) + " MUST equal model definition size of m=" + str(self.m)

    ################################################################################

    """
    setPopulationEi
    Given a data frame containing one column with the zone number (i) and one column
    with the actual data values, fill the Ei population property with data so that
    the position in the Ei numpy array is the zonei field of the data.
    The code is almost identical to the setAttractorsAj method.
    NOTE: max(i) < self.m
    """
    def setPopulationEi(self, df, zoneiColName, dataColName):
        df2 = df.sort_values(by=[zoneiColName])
        self.Ei = df2[dataColName].to_numpy()
        assert len(self.Ei) == self.m, "FATAL: setPopulationEi length Ei=" + str(len(self.Ei)) + " MUST equal model definition size of m=" + str(self.m)

    ################################################################################

    """
    setAttractorsAj
    Given a data frame containing one column with the zone number (j) and one column
    with the actual data values, fill the Aj attractors property with data so that
    the position in the Aj numpy array is the zonej field of the data.
    The code is almost identical to the setPopulationEi method.
    NOTE: max(j) < self.n
    """
    def setAttractorsAj(self, df, zonejColName, dataColName):
        df2 = df.sort_values(by=[zonejColName])
        self.Aj = df2[dataColName].to_numpy()
        assert len(self.Aj) == self.n, "FATAL: setAttractorsAj length Aj=" + str(len(self.Aj)) + " MUST equal model definition size of n=" + str(self.n)

    ################################################################################

    """
    setCostsMatrix
    Assign the cost matrix for the model to use when it runs.
    NOTE: this MUST match the m x n order of the model and be a numpy array
    """
    def setCostMatrixCij(self, cij_0, cij_1, cij_2):
        i, j = cij_0.shape  # Hopefully cij_0.shape = cij_1.shape = cij_2.shape
        assert i == self.m, "FATAL: setCostsMatrix cij matrix is the wrong size, cij.m=" + str(i) + " MUST match model definition of m=" + str(self.m)
        assert j == self.n, "FATAL: setCostsMatrix cij matrix is the wrong size, cij.n=" + str(j) + " MUST match model definition of n=" + str(self.n)
        self.cij_0 = cij_0
        self.cij_1 = cij_1
        self.cij_2 = cij_2

    ################################################################################

    """
    setObsMatrix
    Assign the cost matrix for the model to use when it runs.
    NOTE: this MUST match the m x n order of the model and be a numpy array
    """
    def setObsMatrix(self, SObs_0, SObs_1, SObs_2):
        i, j = SObs_0.shape  # Hopefully cij_0.shape = SObs_0.shape = SObs_0.shape
        assert i == self.m, "FATAL: setCostsMatrix cij matrix is the wrong size, cij.m=" + str(
            i) + " MUST match model definition of m=" + str(self.m)
        assert j == self.n, "FATAL: setCostsMatrix cij matrix is the wrong size, cij.n=" + str(
            j) + " MUST match model definition of n=" + str(self.n)
        self.SObs_0 = SObs_0
        self.SObs_1 = SObs_1
        self.SObs_2 = SObs_2

    ################################################################################

    """
    computeCBar
    Compute average trip length TODO: VERY COMPUTATIONALLY INTENSIVE - FIX IT
    @param Sij trips matrix containing the flow numbers between MSOA (i) and schools (j)
    @param cij trip times between i and j
    """
    def computeCBar(self, Sij, cij):
        CNumerator = np.sum(Sij * cij)
        CDenominator = np.sum(Sij)
        cbar = CNumerator / CDenominator
        return cbar

    ################################################################################

    """
        Calculate Dj for a trips matrix.
        Two methods are presented here, one which is simple and very slow and one
        which uses python vector maths and is much faster. Once 2 is proven equal
        to 1, then it can be used exclusively. This function is mainly used for
        testing with the TensorFlow and other implementations.
        """

    def calculateDj(self, Tij):
        (M, N) = np.shape(Tij)
        Dj = np.zeros(N)
        Dj = Tij.sum(axis=0)
        return Dj

    ###############################################################################

    """
    run Model run3modes
    Quant model for three modes of transport
    @returns Sij predicted flows between i and j
    """
    def run3modes(self):
        # run model
        # i = employment zone
        # j = residential zone
        # Ei = number of jobs at MSOA location
        # Aj = attractor of HH (number of dwellings)
        # cij_mode = travel cost for "mode" (i.e. road, bus, rail)
        # Modes: Road = 0, Bus = 1, Rail = 2
        # Beta = Beta values for three modes - this is also output
        # QUANT data:
        # Observed trips data: "SObs_1.bin", "SObs_2.bin", "SObs_3.bin"
        # Travel cost per mode: "dis_roads_min.bin", "dis_bus_min.bin", "dis_gbrail_min.bin"
        # Note the use of 1,2,3 for modes in the files different from 0,1,2 in the code.
        # Returns predicted flows per mode: "SPred_1.bin", "SPred_2.bin", "SPred_3.bin"

        # Initialisation of parameters
        converged = False  # initialise convergence check param
        n_modes = 3  # Number of modes
        cij_k = [self.cij_0, self.cij_1, self.cij_2]  # list of cost matrices
        SObs_k = [self.SObs_0, self.SObs_1, self.SObs_2]  # list of obs trips matrices

        # Set up Beta for modes 0, 1 and 2 to 1.0
        Beta = np.ones(n_modes)

        # Compute sum of origins and destinations

        '''
        # OiObs : vector with dimension = number of oringins
        OiObs = np.zeros(self.n)
        for k in range(n_modes):
            OiObs += SObs_k[k].sum(axis=1)
        '''

        # DjObs : vector with dimension = number of destinations
        DjObs = [[] for i in range(n_modes)]
        for k in range(n_modes):
            DjObs[k] = np.zeros(self.n)
        for k in range(n_modes):
            DjObs[k] += SObs_k[k].sum(axis=1)

        DjPred = [[] for i in range(n_modes)]
        DjPredSum = np.zeros(n_modes)
        DjObsSum = np.zeros(n_modes)
        delta = np.zeros(n_modes)


        # Convergence loop:
        print("Calibrating the model...")
        iteration = 0
        while converged != True:
            iteration += 1
            print("Iteration: ", iteration)

            # Initialise variables:
            Sij = [[] for i in range(n_modes)]  # initialise Sij with a number of empty lists equal to n_modes

            # hold copy of pre multiplied copies of -Beta_k * cij[k] for each mode
            ExpMBetaCijk = [[] for k in range(n_modes)]
            for kk in range(n_modes):
                ExpMBetaCijk[kk] = np.exp(-Beta[kk] * cij_k[kk])

            for k in range(n_modes):  # mode loop
                Sij[k] = np.zeros(self.m * self.n).reshape(self.m, self.n)
                for i in range(self.m):
                    denom = 0
                    for kk in range(n_modes):
                        denom += np.sum(self.Aj * ExpMBetaCijk[kk][i, :])
                    Sij2 = self.Ei[i] * (self.Aj * ExpMBetaCijk[k][i, :] / denom)
                    Sij[k][i, :] = Sij2  # put answer slice back in return array

            # Calibration with CBar values
            # Calculate mean predicted trips and mean observed trips (this is CBar)
            CBarPred = np.zeros(n_modes)
            CBarObs = np.zeros(n_modes)
            delta = np.ones(n_modes)
            for k in range(n_modes):
                CBarPred[k] = self.computeCBar(Sij[k], cij_k[k])
                CBarObs[k] = self.computeCBar(SObs_k[k], cij_k[k])
                delta[k] = np.absolute(CBarPred[k] - CBarObs[k])  # the aim is to minimise delta[0]+delta[1]+...
            # delta check on all betas (Beta0, Beta1, Beta2) stopping condition for convergence
            # double gradient descent search on Beta0 and Beta1 and Beta2
            converged = True
            for k in range(n_modes):
                if (delta[k] / CBarObs[k] > 0.001):
                    Beta[k] = Beta[k] * CBarPred[k] / CBarObs[k]
                    converged = False
            '''
            # Calibration with Observed flows
            for k in range(n_modes):
                DjPred[k] = self.calculateDj(Sij[k])
                DjPredSum[k] = np.sum(DjPred[k])
                DjObsSum[k] = np.sum(DjObs[k])
                delta[k] = DjPredSum[k] - DjObsSum[k]
            # delta check on beta stopping condition for convergence
            # gradient descent search on beta
            converged = True
            for k in range(n_modes):
                if (delta[k] / DjObsSum[k] > 0.001):
                    Beta[k] = Beta[k] * DjPredSum[k] / DjObsSum[k]
                    converged = False
            '''
            CBarPred = np.zeros(n_modes)
            # Calculate CBar
            for k in range(n_modes):
                CBarPred[k] = self.computeCBar(Sij[k], cij_k[k])

            # Debug:
            # commuter sum blocks
            TotalSij_roads = Sij[0].sum()
            TotalSij_bus = Sij[1].sum()
            TotalSij_rail = Sij[2].sum()
            TotalEi = self.Ei.sum()  # total jobs = pu+pr above
            # print("i= {0:d} beta_roads={1:.6f} beta_bus={2:.6f} beta_rail={3:.6f} cbar_pred_roads={4:.1f} cbar_pred_busr={5:.1f} cbar_pred_rail={6:.1f}"
            #         .format(iteration, Beta[0], Beta[1], Beta[2], CBarPred[0], CBarPred[1], CBarPred[2]))
            # print("TotalSij_roads={0:.1f} TotalSij_bus={1:.1f} TotalSij_rail={2:.1f} Total={3:.1f} ({4:.1f})"
            #       .format(TotalSij_roads, TotalSij_bus, TotalSij_rail, TotalSij_roads + TotalSij_bus + TotalSij_rail, TotalEi))

        return Sij, Beta, CBarPred  # Note that Sij = [Sij_k=0 , Sij_k=1, Sij_k=2] and CBarPred = [CBarPred_0, CBarPred_1, CBarPred_2]

    ################################################################################

    """
    run Model run3modes_NoCalibration
    Quant model for three modes of transport without calibration
    @returns Sij predicted flows between i and j
    """
    def run3modes_NoCalibration(self, Beta):
        n_modes = len(Beta)  # Number of modes
        print("Running model for ", n_modes, " modes.")

        # Initialise variables:
        Sij = [[] for i in range(n_modes)]  # initialise Sij with a number of empty lists equal to n_modes
        cij_k = [self.cij_0, self.cij_1, self.cij_2]  # list of cost matrices

        # hold copy of pre multiplied copies of -Beta_k * cij[k] for each mode
        ExpMBetaCijk = [[] for k in range(n_modes)]
        for kk in range(n_modes):
            ExpMBetaCijk[kk] = np.exp(-Beta[kk] * cij_k[kk])

        for k in range(n_modes):  # mode loop
            Sij[k] = np.zeros(self.m * self.n).reshape(self.m, self.n)
            for i in range(self.m):
                denom = 0
                for kk in range(n_modes):
                    denom += np.sum(self.Aj * ExpMBetaCijk[kk][i, :])
                Sij2 = self.Ei[i] * (self.Aj * ExpMBetaCijk[k][i, :] / denom)
                Sij[k][i, :] = Sij2  # put answer slice back in return array

        CBarPred = np.zeros(n_modes)  # initialise CBarPred
        for k in range(n_modes):
            CBarPred[k] = self.computeCBar(Sij[k], cij_k[k])

        return Sij, CBarPred

    ################################################################################

    """
    computeProbabilities3modes
    Compute the probability of a flow from an MSOA zone to any (i.e. all) of the possible point zones
    """
    def computeProbabilities3modes(self, Sij):
        print("Computing probabilities")
        n_modes = 3
        probSij = [[] for i in range(n_modes)]  # initialise Sij with a number of empty list equal to n_modes

        for k in range(n_modes):
            probSij[k] = np.arange(self.m * self.n, dtype=np.float64).reshape(self.m, self.n)
            for i in range(self.m):
                sum = np.sum(Sij[k][i,])
                if sum <= 0:
                    sum = 1  # catch for divide by zero - just let the zero probs come through to the final matrix
                probSij[k][i,] = Sij[k][i,] / sum

        return probSij
    
class QUANTRetailModel(QUANTLHModel):
    """
    constructor
    @param n number of residential zones
    @param m number of retail zones
    """
    def __init__(self,m,n):
        #constructor
        super().__init__(m,n)

    ################################################################################

    """
    loadGeolytixData
    @param filename Name of file to load - this is the Geolytix restricted access data with
    the floorspace and retail data
    @returns DataFrame containing [key,zonei,east,north] and [zonei,Modelled turnover annual]
    """
    @staticmethod
    def loadGeolytixData(filename):
        missing_values = ['-', 'n/a', 'na', '--', ' -   ']
        df = pd.read_csv(filename,usecols=['id','fascia','modelled sq ft','Modelled turnover annual','bng_e','bng_n'], na_values=missing_values)
        df.dropna(axis=0,inplace=True)
        df.reset_index(drop=True,inplace=True) # IMPORTANT, otherwise indexes remain for ALL the rows i.e. idx=0..OriginalN NOT true row count!
        dfzones = pd.DataFrame({'id':df.id,'zonei':df.index,'east':df.bng_e,'north':df.bng_n})
        dfattractors = pd.DataFrame({'zonei':df.index,'Modelled turnover annual':df['Modelled turnover annual']}) # could also used floorspace
        return dfzones, dfattractors
    
def costMSOAToPoint_3modes(cij_roads, cij_bus, cij_rail, dfPoints, OXF_MSOA_list):
    # const to define what speed we travel the additional distance to the retail point e.g. 30mph = 13 ms-1
    metresPerSec_roads = 13.0 # 30 miles/h = 47 km/h
    metresPerSec_bus = 13.0  # 30 miles/h = 47 km/h
    metresPerSec_rail = 13.0  # 30 miles/h = 47 km/h

    # read in the road, bus and rail centroids for the cij matrix
    df_roads = pd.read_csv(os.path.join('data', 'roadcentroidlookup_QC.csv'), index_col='zonecode')
    df_bus = pd.read_csv(os.path.join('data', 'buscentroidlookup_QC.csv'), index_col='zonecode')
    df_rail = pd.read_csv(os.path.join('data', 'gbrailcentroidlookup_QC.csv'), index_col='zonecode')

    # Filter out Oxfordshire from EWS files
    df_roads = df_roads.loc[OXF_MSOA_list]  # Filter rows
    df_bus = df_bus.loc[OXF_MSOA_list]  # Filter rows
    df_rail = df_rail.loc[OXF_MSOA_list]  # Filter rows

    df_roads['zonecode'] = df_roads.index  # turn the index (i.e. MSOA codes) back into a columm
    df_bus['zonecode'] = df_bus.index  # turn the index (i.e. MSOA codes) back into a columm
    df_rail['zonecode'] = df_rail.index  # turn the index (i.e. MSOA codes) back into a columm

    # Reset indexes
    df_roads.reset_index(drop=True, inplace=True)
    df_bus.reset_index(drop=True, inplace=True)
    df_rail.reset_index(drop=True, inplace=True)

    # Overwrite the zonei column with the new index
    df_roads['zonei'] = df_roads.index
    df_bus['zonei'] = df_bus.index
    df_rail['zonei'] = df_rail.index

    # code this into a geodataframe so we can make a spatial index
    gdf_roads = gpd.GeoDataFrame(df_roads, crs='epsg:4326', geometry=gpd.points_from_xy(df_roads.vertex_lon, df_roads.vertex_lat))
    gdf_bus = gpd.GeoDataFrame(df_bus, crs='epsg:4326', geometry=gpd.points_from_xy(df_bus.vertex_lon, df_bus.vertex_lat))
    gdf_rail = gpd.GeoDataFrame(df_rail, crs='epsg:4326', geometry=gpd.points_from_xy(df_rail.vertex_lon, df_rail.vertex_lat))

    # but it's lat/lon and we want east/north, convert crs:
    centroids_roads = gdf_roads.to_crs("EPSG:27700")
    centroids_bus = gdf_bus.to_crs("EPSG:27700")
    centroids_rail = gdf_rail.to_crs("EPSG:27700")

    dest_unary_roads = centroids_roads["geometry"].unary_union  # and need this join for the centroid points nearest lookup
    dest_unary_bus = centroids_bus["geometry"].unary_union  # and need this join for the centroid points nearest lookup
    dest_unary_rail = centroids_rail["geometry"].unary_union  # and need this join for the centroid points nearest lookup

    # create a new MSOA to points cost matix
    m, n = cij_roads.shape
    p, cols = dfPoints.shape
    # print("array size = ", p, m)

    cijpoint_roads = np.zeros(m * p, dtype=np.float64).reshape(m, p)  # so m=MSOA and p=points index
    cijpoint_bus = np.zeros(m * p, dtype=np.float64).reshape(m, p)  # so m=MSOA and p=points index
    cijpoint_rail = np.zeros(m * p, dtype=np.float64).reshape(m, p)  # so m=MSOA and p=points index

    # now make the amended cost function
    count = 0
    for row in dfPoints.itertuples(index=False):  # NOTE: iterating over Pandas rows is supposed to be bad - how else to do this?
        if (count % 50 == 0): print("costs::costMSOAToPoint ", count, "/", p)
        count += 1

        p_zonei = getattr(row, 'zonei')
        p_east = getattr(row, 'east')
        p_north = getattr(row, 'north')

        near_roads = nearest_points(Point(p_east, p_north), dest_unary_roads)
        near_bus = nearest_points(Point(p_east, p_north), dest_unary_bus)
        near_rail = nearest_points(Point(p_east, p_north), dest_unary_rail)

        match_geom_roads = centroids_roads.loc[centroids_roads.geometry == near_roads[1]]
        match_geom_bus = centroids_bus.loc[centroids_bus.geometry == near_bus[1]]
        match_geom_rail = centroids_rail.loc[centroids_rail.geometry == near_rail[1]]

        pmsoa_zonei_roads = int(match_geom_roads.zonei.iloc[0])  # closest point msoa zone
        pmsoa_zonei_bus = int(match_geom_bus.zonei.iloc[0])  # closest point msoa zone
        pmsoa_zonei_rail = int(match_geom_rail.zonei.iloc[0])  # closest point msoa zone

        pmsoa_pt_roads = match_geom_roads.geometry
        pmsoa_pt_bus = match_geom_bus.geometry
        pmsoa_pt_rail = match_geom_rail.geometry

        pmsoa_east_roads = float(pmsoa_pt_roads.centroid.x.iloc[0])
        pmsoa_east_bus = float(pmsoa_pt_bus.centroid.x.iloc[0])
        pmsoa_east_rail = float(pmsoa_pt_rail.centroid.x.iloc[0])

        pmsoa_north_roads = float(pmsoa_pt_roads.centroid.y.iloc[0])
        pmsoa_north_bus = float(pmsoa_pt_bus.centroid.y.iloc[0])
        pmsoa_north_rail = float(pmsoa_pt_rail.centroid.y.iloc[0])

        dx_roads = p_east - pmsoa_east_roads
        dx_bus = p_east - pmsoa_east_bus
        dx_rail = p_east - pmsoa_east_rail

        dy_roads = p_north - pmsoa_north_roads
        dy_bus = p_north - pmsoa_north_bus
        dy_rail = p_north - pmsoa_north_rail

        dist_roads = np.sqrt(dx_roads * dx_roads + dy_roads * dy_roads)  # dist between point and centroid used for shortest path
        dist_bus = np.sqrt(dx_bus * dx_bus + dy_bus * dy_bus)  # dist between point and centroid used for shortest path
        dist_rail = np.sqrt(dx_rail * dx_rail + dy_rail * dy_rail)  # dist between point and centroid used for shortest path

        # work out an additional delta cost based on increased time getting from this point to the centroid
        deltaCost_roads = (dist_roads / metresPerSec_roads) / 60.0  # transit time in mins
        deltaCost_bus = (dist_bus / metresPerSec_bus) / 60.0  # transit time in mins
        deltaCost_rail = (dist_rail / metresPerSec_rail) / 60.0  # transit time in mins

        # now write every cij value for msoa_zonei to p_zonei (closest) PLUS deltaCose for p_zonei to actual point
        for i in range(n):
            C1_roads = cij_roads[pmsoa_zonei_roads, i]  # yes, this is right for a trip from MSOA to closest point MSOA - QUANT is BACKWARDS
            C1_bus = cij_bus[pmsoa_zonei_bus, i]  # yes, this is right for a trip from MSOA to closest point MSOA - QUANT is BACKWARDS
            C1_rail = cij_rail[pmsoa_zonei_rail, i]  # yes, this is right for a trip from MSOA to closest point MSOA - QUANT is BACKWARDS

            cijpoint_roads[i, p_zonei] = C1_roads + deltaCost_roads
            cijpoint_bus[i, p_zonei] = C1_bus + deltaCost_bus
            cijpoint_rail[i, p_zonei] = C1_rail + deltaCost_rail

            # NOTE: you can only go in one direction with a matrix that is asymmetric

    return cijpoint_roads, cijpoint_bus, cijpoint_rail

def run3modes_NoCalibration(self, Beta):
        n_modes = len(Beta)  # Number of modes
        print("Running model for ", n_modes, " modes.")

        # Initialise variables:
        Sij = [[] for i in range(n_modes)]  # initialise Sij with a number of empty lists equal to n_modes
        cij_k = [self.cij_0, self.cij_1, self.cij_2]  # list of cost matrices

        # hold copy of pre multiplied copies of -Beta_k * cij[k] for each mode
        ExpMBetaCijk = [[] for k in range(n_modes)]
        for kk in range(n_modes):
            ExpMBetaCijk[kk] = np.exp(-Beta[kk] * cij_k[kk])

        for k in range(n_modes):  # mode loop
            Sij[k] = np.zeros(self.m * self.n).reshape(self.m, self.n)
            for i in range(self.m):
                denom = 0
                for kk in range(n_modes):
                    denom += np.sum(self.Aj * ExpMBetaCijk[kk][i, :])
                Sij2 = self.Ei[i] * (self.Aj * ExpMBetaCijk[k][i, :] / denom)
                Sij[k][i, :] = Sij2  # put answer slice back in return array

        CBarPred = np.zeros(n_modes)  # initialise CBarPred
        for k in range(n_modes):
            CBarPred[k] = self.computeCBar(Sij[k], cij_k[k])

        return Sij, CBarPred

# %%
OXF_MSOA_df =  pd.read_excel('data/msoa_data.xlsx', usecols=["msoa11cd"]) # import file with OXF MSOA codes
OXF_MSOA_df.columns = ['areakey'] # rename column "msoa11cd" to "areakey"
OXF_MSOA_list = OXF_MSOA_df['areakey'].tolist()
del OXF_MSOA_list[-1]

zonecodes_EWS = pd.read_csv('data/EWS_ZoneCodes.csv')
zonecodes_EWS.set_index('areakey')
zonecodes_EWS_list = zonecodes_EWS['areakey'].tolist()

cij_road_EWS = loadQUANTMatrix('data/dis_roads_min.bin')
cij_road_EWS_df = pd.DataFrame(cij_road_EWS, index=zonecodes_EWS_list, columns=zonecodes_EWS_list)
cij_road_OXF_df = cij_road_EWS_df[OXF_MSOA_list]
cij_road_OXF_df = cij_road_OXF_df.loc[OXF_MSOA_list]
cij_road_OXF = cij_road_OXF_df.to_numpy()
cij_road_OXF[cij_road_OXF < 1] = 1 

cij_bus_EWS = loadQUANTMatrix('data/dis_bus_min.bin')
cij_bus_EWS_df = pd.DataFrame(cij_bus_EWS, index=zonecodes_EWS_list, columns=zonecodes_EWS_list) # turn the numpy array into a pd dataframe, (index and columns: MSOA codes)
cij_bus_OXF_df = cij_bus_EWS_df[OXF_MSOA_list]  # Create OXF df filtering EWS columns
cij_bus_OXF_df = cij_bus_OXF_df.loc[OXF_MSOA_list]  # Filter rows
cij_bus_OXF = cij_bus_OXF_df.to_numpy()  # numpy matrix for OXF (same format as utils loadQUANTMatrix)
cij_bus_OXF[cij_bus_OXF < 1] = 1  # lower limit of 1 minute links

cij_rail_EWS = loadQUANTMatrix('data/dis_gbrail_min.bin')
cij_rail_EWS_df = pd.DataFrame(cij_rail_EWS, index=zonecodes_EWS_list, columns=zonecodes_EWS_list) # turn the numpy array into a pd dataframe, (index and columns: MSOA codes)
cij_rail_OXF_df = cij_rail_EWS_df[OXF_MSOA_list]  # Create OXF df filtering EWS columns
cij_rail_OXF_df = cij_rail_OXF_df.loc[OXF_MSOA_list]  # Filter rows
cij_rail_OXF = cij_rail_OXF_df.to_numpy()  # numpy matrix for OXF (same format as utils loadQUANTMatrix)
cij_rail_OXF[cij_rail_OXF < 1] = 1  # lower limit of 1 minute links

SObs_road_EWS = loadQUANTMatrix('data/SObs_1.bin')
SObs_road_EWS_df = pd.DataFrame(SObs_road_EWS, index=zonecodes_EWS_list, columns=zonecodes_EWS_list) # turn the numpy array into a pd dataframe, (index and columns: MSOA codes)
SObs_road_OXF_df = SObs_road_EWS_df[OXF_MSOA_list]  # Create OXF df filtering EWS columns
SObs_road_OXF_df = SObs_road_OXF_df.loc[OXF_MSOA_list]  # Filter rows
SObs_road_OXF = SObs_road_OXF_df.to_numpy()  # numpy matrix for OXF (same format as utils loadQUANTMatrix)

SObs_bus_EWS = loadQUANTMatrix('data/SObs_2.bin')
SObs_bus_EWS_df = pd.DataFrame(SObs_bus_EWS, index=zonecodes_EWS_list, columns=zonecodes_EWS_list)  # turn the numpy array into a pd dataframe, (index and columns: MSOA codes)
SObs_bus_OXF_df = SObs_bus_EWS_df[OXF_MSOA_list]  # Create OXF df filtering EWS columns
SObs_bus_OXF_df = SObs_bus_OXF_df.loc[OXF_MSOA_list]  # Filter rows
SObs_bus_OXF = SObs_bus_OXF_df.to_numpy()  # numpy matrix for OXF (same format as utils loadQUANTMatrix)

SObs_rail_EWS = loadQUANTMatrix('data/SObs_3.bin')
SObs_rail_EWS_df = pd.DataFrame(SObs_rail_EWS, index=zonecodes_EWS_list, columns=zonecodes_EWS_list)  # turn the numpy array into a pd dataframe, (index and columns: MSOA codes)
SObs_rail_OXF_df = SObs_rail_EWS_df[OXF_MSOA_list]  # Create OXF df filtering EWS columns
SObs_rail_OXF_df = SObs_rail_OXF_df.loc[OXF_MSOA_list]  # Filter rows
SObs_rail_OXF = SObs_rail_OXF_df.to_numpy()  # numpy matrix for OXF (same format as utils loadQUANTMatrix)

dfEW = pd.read_csv('data/QS103EW_MSOA.csv')
dfEW['count_allpeople'] = dfEW['Age: All categories: Age; measures: Value'] # you could just rename the col, not copy
dfEW2 = pd.DataFrame({'geography code': dfEW['geography code'], 'count_allpeople': dfEW['count_allpeople']})

dfS = pd.read_csv('data/QS103SC_DZ2001.csv') # join on "Unnamed: 0", it's blank! This is the datazone code field
dfS.set_index('Unnamed: 0')
dfSLookup = pd.read_csv('data/DZ2001Lookup.csv') # join on ZONECODE, which is the datazone code
dfS = dfS.join(other=dfSLookup.set_index('ZONECODE'),on='Unnamed: 0')
dfS['count_allpeople'] = dfS['All people']
dfS2 = dfS.groupby(['IZ_CODE']).agg({'count_allpeople': "sum"})
dfS3 = pd.DataFrame({'msoaiz': dfS2.index, 'count_allpeople': dfS2['count_allpeople'] })

dfEW2.reset_index()
dfS3.reset_index()
dfEW2.columns=['msoaiz','count_allpeople']
dfEWS = pd.concat([dfEW2,dfS3])

dfPopMSOAPopulation_EWS = pd.read_csv('data/totalpopulation_englandwalesscotland_msoaiz.csv', usecols=['msoaiz', 'count_allpeople'], index_col='msoaiz') 

dfPopMSOAPopulation_OXF = dfPopMSOAPopulation_EWS.loc[OXF_MSOA_list]  # Filter rows
dfPopMSOAPopulation_OXF.sort_index(inplace=True)
dfPopMSOAPopulation_OXF['msoaiz'] = dfPopMSOAPopulation_OXF.index  # turn the index (i.e. MSOA codes) back into a columm
dfPopMSOAPopulation_OXF.reset_index(drop=True, inplace=True)  # IMPORTANT, otherwise indexes remain for ALL the rows i.e. idx=0..OriginalN NOT true row count!
popretailPopulation = dfPopMSOAPopulation_OXF.join(other=zonecodes_EWS.set_index('areakey'), on='msoaiz') 

retailpoints_EWS = pd.read_csv('data/geolytix_retailpoints_open_regression.csv')
OXF_postcodes_df = pd.read_excel('data/Oxfordshire_postcodes.xlsx')  # df containing: Postcode,Latitude,Longitude,Eastings,Northings
OXF_postcodes_df['DistrictCode'] = OXF_postcodes_df['pcd'].str[:-3]  # create column with district code
OXF_DistrictCodes = OXF_postcodes_df['DistrictCode'].tolist()  # save the district codes into a list
open_geolitix_OXF = retailpoints_EWS.loc[retailpoints_EWS['postcode'].str[:-4].isin(OXF_DistrictCodes)]  # Filter rows (-4 because of the blank space in the middle of the postcode)
open_geolitix_OXF.reset_index(drop=True, inplace=True)
# Out:
# loadQUANTMatrix::m= 8436 n= 8436
# loadQUANTMatrix::m= 8436 n= 8436
# loadQUANTMatrix::m= 8436 n= 8436
# loadQUANTMatrix::m= 8436 n= 8436
# loadQUANTMatrix::m= 8436 n= 8436
# loadQUANTMatrix::m= 8436 n= 8436

# %%
df = open_geolitix_OXF.sort_values('Modelled turnover annual')

def remover_smallest_10_percentage(group):
    return group.tail(int(0.9 * len(group)))

def remover_smallest_20_percentage(group):
    return group.tail(int(0.8 * len(group)))

def remover_smallest_30_percentage(group):
    return group.tail(int(0.7 * len(group)))

def remover_smallest_40_percentage(group):
    return group.tail(int(0.6 * len(group)))

def remover_smallest_50_percentage(group):
    return group.tail(int(0.5 * len(group)))

df_10 = df.groupby('modelled sq ft').apply(remover_smallest_10_percentage).reset_index(drop=True)
df_20 = df.groupby('modelled sq ft').apply(remover_smallest_20_percentage).reset_index(drop=True)
df_30 = df.groupby('modelled sq ft').apply(remover_smallest_30_percentage).reset_index(drop=True)
df_40 = df.groupby('modelled sq ft').apply(remover_smallest_40_percentage).reset_index(drop=True)
df_50 = df.groupby('modelled sq ft').apply(remover_smallest_50_percentage).reset_index(drop=True)
df_10.to_csv('data/geolytix_retailpoints_open_regression_OXF_10.csv')
df_20.to_csv('data/geolytix_retailpoints_open_regression_OXF_20.csv')
df_30.to_csv('data/geolytix_retailpoints_open_regression_OXF_30.csv')
df_40.to_csv('data/geolytix_retailpoints_open_regression_OXF_40.csv')
df_50.to_csv('data/geolytix_retailpoints_open_regression_OXF_50.csv')

# %%
popretailZones, popretailAttractors = QUANTRetailModel.loadGeolytixData('data/geolytix_retailpoints_open_regression_OXF.csv')
popretailZones_10, popretailAttractors_10 = QUANTRetailModel.loadGeolytixData('data/geolytix_retailpoints_open_regression_OXF_10.csv')
popretailZones_20, popretailAttractors_20 = QUANTRetailModel.loadGeolytixData('data/geolytix_retailpoints_open_regression_OXF_20.csv')
popretailZones_30, popretailAttractors_30 = QUANTRetailModel.loadGeolytixData('data/geolytix_retailpoints_open_regression_OXF_30.csv')
popretailZones_40, popretailAttractors_40 = QUANTRetailModel.loadGeolytixData('data/geolytix_retailpoints_open_regression_OXF_40.csv')
popretailZones_50, popretailAttractors_50 = QUANTRetailModel.loadGeolytixData('data/geolytix_retailpoints_open_regression_OXF_50.csv')

# %%
retailpoints_cij_roads, retailpoints_cij_bus, retailpoints_cij_rail = costMSOAToPoint_3modes(cij_road_OXF, cij_bus_OXF, cij_rail_OXF, popretailZones, OXF_MSOA_list)
retailpoints_cij_roads_10, retailpoints_cij_bus_10, retailpoints_cij_rail_10 = costMSOAToPoint_3modes(cij_road_OXF, cij_bus_OXF, cij_rail_OXF, popretailZones_10, OXF_MSOA_list)
retailpoints_cij_roads_20, retailpoints_cij_bus_20, retailpoints_cij_rail_20 = costMSOAToPoint_3modes(cij_road_OXF, cij_bus_OXF, cij_rail_OXF, popretailZones_20, OXF_MSOA_list)
retailpoints_cij_roads_30, retailpoints_cij_bus_30, retailpoints_cij_rail_30 = costMSOAToPoint_3modes(cij_road_OXF, cij_bus_OXF, cij_rail_OXF, popretailZones_30, OXF_MSOA_list)
retailpoints_cij_roads_40, retailpoints_cij_bus_40, retailpoints_cij_rail_40 = costMSOAToPoint_3modes(cij_road_OXF, cij_bus_OXF, cij_rail_OXF, popretailZones_40, OXF_MSOA_list)
retailpoints_cij_roads_50, retailpoints_cij_bus_50, retailpoints_cij_rail_50 = costMSOAToPoint_3modes(cij_road_OXF, cij_bus_OXF, cij_rail_OXF, popretailZones_50, OXF_MSOA_list)
# Out:
# costs::costMSOAToPoint  0 / 520
# costs::costMSOAToPoint  50 / 520
# costs::costMSOAToPoint  100 / 520
# costs::costMSOAToPoint  150 / 520
# costs::costMSOAToPoint  200 / 520
# costs::costMSOAToPoint  250 / 520
# costs::costMSOAToPoint  300 / 520
# costs::costMSOAToPoint  350 / 520
# costs::costMSOAToPoint  400 / 520
# costs::costMSOAToPoint  450 / 520
# costs::costMSOAToPoint  500 / 520
# costs::costMSOAToPoint  0 / 466
# costs::costMSOAToPoint  50 / 466
# costs::costMSOAToPoint  100 / 466
# costs::costMSOAToPoint  150 / 466
# costs::costMSOAToPoint  200 / 466
# costs::costMSOAToPoint  250 / 466
# costs::costMSOAToPoint  300 / 466
# costs::costMSOAToPoint  350 / 466
# costs::costMSOAToPoint  400 / 466
# costs::costMSOAToPoint  450 / 466
# costs::costMSOAToPoint  0 / 414
# costs::costMSOAToPoint  50 / 414
# costs::costMSOAToPoint  100 / 414
# costs::costMSOAToPoint  150 / 414
# costs::costMSOAToPoint  200 / 414
# costs::costMSOAToPoint  250 / 414
# costs::costMSOAToPoint  300 / 414
# costs::costMSOAToPoint  350 / 414
# costs::costMSOAToPoint  400 / 414
# costs::costMSOAToPoint  0 / 363
# costs::costMSOAToPoint  50 / 363
# costs::costMSOAToPoint  100 / 363
# costs::costMSOAToPoint  150 / 363
# costs::costMSOAToPoint  200 / 363
# costs::costMSOAToPoint  250 / 363
# costs::costMSOAToPoint  300 / 363
# costs::costMSOAToPoint  350 / 363
# costs::costMSOAToPoint  0 / 310
# costs::costMSOAToPoint  50 / 310
# costs::costMSOAToPoint  100 / 310
# costs::costMSOAToPoint  150 / 310
# costs::costMSOAToPoint  200 / 310
# costs::costMSOAToPoint  250 / 310
# costs::costMSOAToPoint  300 / 310
# costs::costMSOAToPoint  0 / 259
# costs::costMSOAToPoint  50 / 259
# costs::costMSOAToPoint  100 / 259
# costs::costMSOAToPoint  150 / 259
# costs::costMSOAToPoint  200 / 259
# costs::costMSOAToPoint  250 / 259

# %%
m, n = retailpoints_cij_roads.shape
model = QUANTRetailModel(m,n)
model.setAttractorsAj(popretailAttractors,'zonei','Modelled turnover annual')
model.setPopulationEi(popretailPopulation,'zonei','count_allpeople')
model.setCostMatrixCij(retailpoints_cij_roads, retailpoints_cij_bus, retailpoints_cij_rail)
beta = np.array([0.3127422 , 0.07877828, 0.05523665]) # from the Journey to work model calibration
Rij, cbar = model.run3modes_NoCalibration(beta)
popretail_probRij = model.computeProbabilities3modes(Rij)
# Out:
# Running model for  3  modes.
# Computing probabilities

# %%
m, n = retailpoints_cij_roads_10.shape
model = QUANTRetailModel(m,n)
model.setAttractorsAj(popretailAttractors_10,'zonei','Modelled turnover annual')
model.setPopulationEi(popretailPopulation,'zonei','count_allpeople')
model.setCostMatrixCij(retailpoints_cij_roads_10, retailpoints_cij_bus_10, retailpoints_cij_rail_10)
beta = np.array([0.3127422 , 0.07877828, 0.05523665]) # from the Journey to work model calibration
Rij_10, cbar_10 = model.run3modes_NoCalibration(beta)
popretail_probRij_10 = model.computeProbabilities3modes(Rij_10)
# Out:
# Running model for  3  modes.
# Computing probabilities

# %%
m, n = retailpoints_cij_roads_20.shape
model = QUANTRetailModel(m,n)
model.setAttractorsAj(popretailAttractors_20,'zonei','Modelled turnover annual')
model.setPopulationEi(popretailPopulation,'zonei','count_allpeople')
model.setCostMatrixCij(retailpoints_cij_roads_20, retailpoints_cij_bus_20, retailpoints_cij_rail_20)
beta = np.array([0.3127422 , 0.07877828, 0.05523665]) # from the Journey to work model calibration
Rij_20, cbar_20 = model.run3modes_NoCalibration(beta)
popretail_probRij_20 = model.computeProbabilities3modes(Rij_20)
# Out:
# Running model for  3  modes.
# Computing probabilities

# %%
m, n = retailpoints_cij_roads_30.shape
model = QUANTRetailModel(m,n)
model.setAttractorsAj(popretailAttractors_30,'zonei','Modelled turnover annual')
model.setPopulationEi(popretailPopulation,'zonei','count_allpeople')
model.setCostMatrixCij(retailpoints_cij_roads_30, retailpoints_cij_bus_30, retailpoints_cij_rail_30)
beta = np.array([0.3127422 , 0.07877828, 0.05523665]) # from the Journey to work model calibration
Rij_30, cbar_30 = model.run3modes_NoCalibration(beta)
popretail_probRij_30 = model.computeProbabilities3modes(Rij_30)
# Out:
# Running model for  3  modes.
# Computing probabilities

# %%
m, n = retailpoints_cij_roads_40.shape
model = QUANTRetailModel(m,n)
model.setAttractorsAj(popretailAttractors_40,'zonei','Modelled turnover annual')
model.setPopulationEi(popretailPopulation,'zonei','count_allpeople')
model.setCostMatrixCij(retailpoints_cij_roads_40, retailpoints_cij_bus_40, retailpoints_cij_rail_40)
beta = np.array([0.3127422 , 0.07877828, 0.05523665]) # from the Journey to work model calibration
Rij_40, cbar_40 = model.run3modes_NoCalibration(beta)
popretail_probRij_40 = model.computeProbabilities3modes(Rij_40)
# Out:
# Running model for  3  modes.
# Computing probabilities

# %%
m, n = retailpoints_cij_roads_50.shape
model = QUANTRetailModel(m,n)
model.setAttractorsAj(popretailAttractors_50,'zonei','Modelled turnover annual')
model.setPopulationEi(popretailPopulation,'zonei','count_allpeople')
model.setCostMatrixCij(retailpoints_cij_roads_50, retailpoints_cij_bus_50, retailpoints_cij_rail_50)
beta = np.array([0.3127422 , 0.07877828, 0.05523665]) # from the Journey to work model calibration
Rij_50, cbar_50 = model.run3modes_NoCalibration(beta)
popretail_probRij_50 = model.computeProbabilities3modes(Rij_50)
# Out:
# Running model for  3  modes.
# Computing probabilities

# %%
np.savetxt('data/populationretailProbRij_roads_2011_10.csv', popretail_probRij_10[0], delimiter=",")
np.savetxt('data/populationretailProbRij_bus_2011_10.csv', popretail_probRij_10[1], delimiter=",")
np.savetxt('data/populationretailProbRij_rail_2011_10.csv', popretail_probRij_10[2], delimiter=",")
np.savetxt('data/populationretailRij_roads_2011_10.csv', Rij_10[0], delimiter=",")
np.savetxt('data/populationretailRij_bus_2011_10.csv', Rij_10[1], delimiter=",")
np.savetxt('data/populationretailRij_rail_2011_10.csv', Rij_10[2], delimiter=",")

np.savetxt('data/populationretailProbRij_roads_2011_20.csv', popretail_probRij_20[0], delimiter=",")
np.savetxt('data/populationretailProbRij_bus_2011_20.csv', popretail_probRij_20[1], delimiter=",")
np.savetxt('data/populationretailProbRij_rail_2011_20.csv', popretail_probRij_20[2], delimiter=",")
np.savetxt('data/populationretailRij_roads_2011_20.csv', Rij_20[0], delimiter=",")
np.savetxt('data/populationretailRij_bus_2011_20.csv', Rij_20[1], delimiter=",")
np.savetxt('data/populationretailRij_rail_2011_20.csv', Rij_30[2], delimiter=",")

np.savetxt('data/populationretailProbRij_roads_2011_30.csv', popretail_probRij_30[0], delimiter=",")
np.savetxt('data/populationretailProbRij_bus_2011_30.csv', popretail_probRij_30[1], delimiter=",")
np.savetxt('data/populationretailProbRij_rail_2011_30.csv', popretail_probRij_30[2], delimiter=",")
np.savetxt('data/populationretailRij_roads_2011_30.csv', Rij_30[0], delimiter=",")
np.savetxt('data/populationretailRij_bus_2011_30.csv', Rij_30[1], delimiter=",")
np.savetxt('data/populationretailRij_rail_2011_30.csv', Rij_30[2], delimiter=",")

np.savetxt('data/populationretailProbRij_roads_2011_40.csv', popretail_probRij_40[0], delimiter=",")
np.savetxt('data/populationretailProbRij_bus_2011_40.csv', popretail_probRij_40[1], delimiter=",")
np.savetxt('data/populationretailProbRij_rail_2011_40.csv', popretail_probRij_40[2], delimiter=",")
np.savetxt('data/populationretailRij_roads_2011_40.csv', Rij_40[0], delimiter=",")
np.savetxt('data/populationretailRij_bus_2011_40.csv', Rij_40[1], delimiter=",")
np.savetxt('data/populationretailRij_rail_2011_40.csv', Rij_40[2], delimiter=",")

np.savetxt('data/populationretailProbRij_roads_2011_50.csv', popretail_probRij_50[0], delimiter=",")
np.savetxt('data/populationretailProbRij_bus_2011_50.csv', popretail_probRij_50[1], delimiter=",")
np.savetxt('data/populationretailProbRij_rail_2011_50.csv', popretail_probRij_50[2], delimiter=",")
np.savetxt('data/populationretailRij_roads_2011_50.csv', Rij_50[0], delimiter=",")
np.savetxt('data/populationretailRij_bus_2011_50.csv', Rij_50[1], delimiter=",")
np.savetxt('data/populationretailRij_rail_2011_50.csv', Rij_50[2], delimiter=",")

# %%
gdf = gpd.read_file('data/ESRI/MSOA_2011_London_gen_MHW.shp')
gdf = gdf.to_crs('EPSG: 4326')
gdf['geometry'] = gdf['geometry'].centroid
gdf = gdf[['geometry']]

def calc_shortest_paths_ODs_osm(zones_centroids, network):
    list_of_ODs = []
    for c in zones_centroids.geometry:
        graph_clostest_node = ox.nearest_nodes(network, c.x, c.y, return_dist=False)
        list_of_ODs.append(graph_clostest_node)
    return list_of_ODs
# Out:
# /var/folders/63/l2ny8d3j1rl_k0h8ghjdkflm0000gn/T/ipykernel_3219/1128587817.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['geometry'] = gdf['geometry'].centroid

# %%
Zone_nodes = gpd.read_file('data/OXF_MSOA_centroids_WGS84.shp')
Case_Study_Zones = ['London, UK']
    # Case_Study_Zones = ['Oxford'] # Smaller network for test purposes

X = ox.graph_from_place(Case_Study_Zones, network_type='drive')
X = X.to_undirected()

# %%
def calc_shortest_paths_ODs_osm(zones_centroids, network):
    list_of_ODs = []
    for c in zones_centroids.geometry:
        graph_clostest_node = ox.nearest_nodes(network, c.x, c.y, return_dist=False)
        list_of_ODs.append(graph_clostest_node)
    return list_of_ODs

# Convert GeoDataFrame to suitable format for calc_shortest_paths_ODs_osm function
OD_list = calc_shortest_paths_ODs_osm(Zone_nodes, X)

# %%
Flows = []
flows_output_keys = ['data/populationretailRij_roads_2011_10.csv',
                     'data/populationretailRij_bus_2011_10.csv',
                     'data/populationretailRij_roads_2011_30.csv', 
                     'data/populationretailRij_bus_2011_30.csv']

for kk, flows_output_key in enumerate(flows_output_keys):
        Flows.append(pd.read_csv(flows_output_key, header=None))

        # Initialise weights to 0:
        for source, target in X.edges():
            X[source][target][0]["Flows_" + str(kk)] = 0

TOT_count = len(OD_list)
    # print(OD_list)

# %%
for n, i in enumerate(OD_list):
    print("Flows maps creation - iteration ", n+1, " of ", TOT_count)
    sssp_paths = nx.single_source_dijkstra_path(X, i, weight='length') 
    for m, j in enumerate(OD_list):
        for cc in range(len(Flows)):
            if m >= Flows[cc].shape[1]:
                continue  # Skip if m exceeds the number of columns in Flows[cc]
            
            shortest_path = sssp_paths[j] 
            path_edges = zip(shortest_path, shortest_path[1:])

            for edge in list(path_edges):
                X[edge[0]][edge[1]][0]["Flows_" + str(cc)] += Flows[cc].iloc[n, m]
# Out:
# Flows maps creation - iteration  1  of  983
# Flows maps creation - iteration  2  of  983
# Flows maps creation - iteration  3  of  983
# Flows maps creation - iteration  4  of  983
# Flows maps creation - iteration  5  of  983
# Flows maps creation - iteration  6  of  983
# Flows maps creation - iteration  7  of  983
# Flows maps creation - iteration  8  of  983
# Flows maps creation - iteration  9  of  983
# Flows maps creation - iteration  10  of  983
# Flows maps creation - iteration  11  of  983
# Flows maps creation - iteration  12  of  983
# Flows maps creation - iteration  13  of  983
# Flows maps creation - iteration  14  of  983
# Flows maps creation - iteration  15  of  983
# Flows maps creation - iteration  16  of  983
# Flows maps creation - iteration  17  of  983
# Flows maps creation - iteration  18  of  983
# Flows maps creation - iteration  19  of  983
# Flows maps creation - iteration  20  of  983
# Flows maps creation - iteration  21  of  983
# Flows maps creation - iteration  22  of  983
# Flows maps creation - iteration  23  of  983
# Flows maps creation - iteration  24  of  983
# Flows maps creation - iteration  25  of  983
# Flows maps creation - iteration  26  of  983
# Flows maps creation - iteration  27  of  983
# Flows maps creation - iteration  28  of  983
# Flows maps creation - iteration  29  of  983
# Flows maps creation - iteration  30  of  983
# Flows maps creation - iteration  31  of  983
# Flows maps creation - iteration  32  of  983
# Flows maps creation - iteration  33  of  983
# Flows maps creation - iteration  34  of  983
# Flows maps creation - iteration  35  of  983
# Flows maps creation - iteration  36  of  983
# Flows maps creation - iteration  37  of  983
# Flows maps creation - iteration  38  of  983
# Flows maps creation - iteration  39  of  983
# Flows maps creation - iteration  40  of  983
# Flows maps creation - iteration  41  of  983
# Flows maps creation - iteration  42  of  983
# Flows maps creation - iteration  43  of  983
# Flows maps creation - iteration  44  of  983
# Flows maps creation - iteration  45  of  983
# Flows maps creation - iteration  46  of  983
# Flows maps creation - iteration  47  of  983
# Flows maps creation - iteration  48  of  983
# Flows maps creation - iteration  49  of  983
# Flows maps creation - iteration  50  of  983
# Flows maps creation - iteration  51  of  983
# Flows maps creation - iteration  52  of  983
# Flows maps creation - iteration  53  of  983
# Flows maps creation - iteration  54  of  983
# Flows maps creation - iteration  55  of  983
# Flows maps creation - iteration  56  of  983
# Flows maps creation - iteration  57  of  983
# Flows maps creation - iteration  58  of  983
# Flows maps creation - iteration  59  of  983
# Flows maps creation - iteration  60  of  983
# Flows maps creation - iteration  61  of  983
# Flows maps creation - iteration  62  of  983
# Flows maps creation - iteration  63  of  983
# Flows maps creation - iteration  64  of  983
# Flows maps creation - iteration  65  of  983
# Flows maps creation - iteration  66  of  983
# Flows maps creation - iteration  67  of  983
# Flows maps creation - iteration  68  of  983
# Flows maps creation - iteration  69  of  983
# Flows maps creation - iteration  70  of  983
# Flows maps creation - iteration  71  of  983
# Flows maps creation - iteration  72  of  983
# Flows maps creation - iteration  73  of  983
# Flows maps creation - iteration  74  of  983
# Flows maps creation - iteration  75  of  983
# Flows maps creation - iteration  76  of  983
# Flows maps creation - iteration  77  of  983
# Flows maps creation - iteration  78  of  983
# Flows maps creation - iteration  79  of  983
# Flows maps creation - iteration  80  of  983
# Flows maps creation - iteration  81  of  983
# Flows maps creation - iteration  82  of  983
# Flows maps creation - iteration  83  of  983
# Flows maps creation - iteration  84  of  983
# Flows maps creation - iteration  85  of  983
# Flows maps creation - iteration  86  of  983
# Flows maps creation - iteration  87  of  983
# Flows maps creation - iteration  88  of  983
# Flows maps creation - iteration  89  of  983
# Flows maps creation - iteration  90  of  983
# Flows maps creation - iteration  91  of  983
# Flows maps creation - iteration  92  of  983
# Flows maps creation - iteration  93  of  983
# Flows maps creation - iteration  94  of  983
# Flows maps creation - iteration  95  of  983
# Flows maps creation - iteration  96  of  983
# Flows maps creation - iteration  97  of  983
# Flows maps creation - iteration  98  of  983
# Flows maps creation - iteration  99  of  983
# Flows maps creation - iteration  100  of  983
# Flows maps creation - iteration  101  of  983
# Flows maps creation - iteration  102  of  983
# Flows maps creation - iteration  103  of  983
# Flows maps creation - iteration  104  of  983
# Flows maps creation - iteration  105  of  983
# Flows maps creation - iteration  106  of  983
# Flows maps creation - iteration  107  of  983
# Flows maps creation - iteration  108  of  983
# Flows maps creation - iteration  109  of  983
# Flows maps creation - iteration  110  of  983
# Flows maps creation - iteration  111  of  983
# Flows maps creation - iteration  112  of  983
# Flows maps creation - iteration  113  of  983
# Flows maps creation - iteration  114  of  983
# Flows maps creation - iteration  115  of  983
# Flows maps creation - iteration  116  of  983
# Flows maps creation - iteration  117  of  983
# Flows maps creation - iteration  118  of  983
# Flows maps creation - iteration  119  of  983
# Flows maps creation - iteration  120  of  983
# Flows maps creation - iteration  121  of  983
# Flows maps creation - iteration  122  of  983
# Flows maps creation - iteration  123  of  983
# Flows maps creation - iteration  124  of  983
# Flows maps creation - iteration  125  of  983
# Flows maps creation - iteration  126  of  983
# Flows maps creation - iteration  127  of  983
# Flows maps creation - iteration  128  of  983
# Flows maps creation - iteration  129  of  983
# Flows maps creation - iteration  130  of  983
# Flows maps creation - iteration  131  of  983
# Flows maps creation - iteration  132  of  983
# Flows maps creation - iteration  133  of  983
# Flows maps creation - iteration  134  of  983
# Flows maps creation - iteration  135  of  983
# Flows maps creation - iteration  136  of  983
# Flows maps creation - iteration  137  of  983
# Flows maps creation - iteration  138  of  983
# Flows maps creation - iteration  139  of  983
# Flows maps creation - iteration  140  of  983
# Flows maps creation - iteration  141  of  983
# Flows maps creation - iteration  142  of  983
# Flows maps creation - iteration  143  of  983
# Flows maps creation - iteration  144  of  983
# Flows maps creation - iteration  145  of  983
# Flows maps creation - iteration  146  of  983
# Flows maps creation - iteration  147  of  983
# Flows maps creation - iteration  148  of  983
# Flows maps creation - iteration  149  of  983
# Flows maps creation - iteration  150  of  983
# Flows maps creation - iteration  151  of  983
# Flows maps creation - iteration  152  of  983
# Flows maps creation - iteration  153  of  983
# Flows maps creation - iteration  154  of  983
# Flows maps creation - iteration  155  of  983
# Flows maps creation - iteration  156  of  983
# Flows maps creation - iteration  157  of  983
# Flows maps creation - iteration  158  of  983
# Flows maps creation - iteration  159  of  983
# Flows maps creation - iteration  160  of  983
# Flows maps creation - iteration  161  of  983
# Flows maps creation - iteration  162  of  983
# Flows maps creation - iteration  163  of  983
# Flows maps creation - iteration  164  of  983
# Flows maps creation - iteration  165  of  983
# Flows maps creation - iteration  166  of  983
# Flows maps creation - iteration  167  of  983
# Flows maps creation - iteration  168  of  983
# Flows maps creation - iteration  169  of  983
# Flows maps creation - iteration  170  of  983
# Flows maps creation - iteration  171  of  983
# Flows maps creation - iteration  172  of  983
# Flows maps creation - iteration  173  of  983
# Flows maps creation - iteration  174  of  983
# Flows maps creation - iteration  175  of  983
# Flows maps creation - iteration  176  of  983
# Flows maps creation - iteration  177  of  983
# Flows maps creation - iteration  178  of  983
# Flows maps creation - iteration  179  of  983
# Flows maps creation - iteration  180  of  983
# Flows maps creation - iteration  181  of  983
# Flows maps creation - iteration  182  of  983
# Flows maps creation - iteration  183  of  983
# Flows maps creation - iteration  184  of  983
# Flows maps creation - iteration  185  of  983
# Flows maps creation - iteration  186  of  983
# Flows maps creation - iteration  187  of  983
# Flows maps creation - iteration  188  of  983
# Flows maps creation - iteration  189  of  983
# Flows maps creation - iteration  190  of  983
# Flows maps creation - iteration  191  of  983
# Flows maps creation - iteration  192  of  983
# Flows maps creation - iteration  193  of  983
# Flows maps creation - iteration  194  of  983
# Flows maps creation - iteration  195  of  983
# Flows maps creation - iteration  196  of  983
# Flows maps creation - iteration  197  of  983
# Flows maps creation - iteration  198  of  983
# Flows maps creation - iteration  199  of  983
# Flows maps creation - iteration  200  of  983
# Flows maps creation - iteration  201  of  983
# Flows maps creation - iteration  202  of  983
# Flows maps creation - iteration  203  of  983
# Flows maps creation - iteration  204  of  983
# Flows maps creation - iteration  205  of  983
# Flows maps creation - iteration  206  of  983
# Flows maps creation - iteration  207  of  983
# Flows maps creation - iteration  208  of  983
# Flows maps creation - iteration  209  of  983
# Flows maps creation - iteration  210  of  983
# Flows maps creation - iteration  211  of  983
# Flows maps creation - iteration  212  of  983
# Flows maps creation - iteration  213  of  983
# Flows maps creation - iteration  214  of  983
# Flows maps creation - iteration  215  of  983
# Flows maps creation - iteration  216  of  983
# Flows maps creation - iteration  217  of  983
# Flows maps creation - iteration  218  of  983
# Flows maps creation - iteration  219  of  983
# Flows maps creation - iteration  220  of  983
# Flows maps creation - iteration  221  of  983
# Flows maps creation - iteration  222  of  983
# Flows maps creation - iteration  223  of  983
# Flows maps creation - iteration  224  of  983
# Flows maps creation - iteration  225  of  983
# Flows maps creation - iteration  226  of  983
# Flows maps creation - iteration  227  of  983
# Flows maps creation - iteration  228  of  983
# Flows maps creation - iteration  229  of  983
# Flows maps creation - iteration  230  of  983
# Flows maps creation - iteration  231  of  983
# Flows maps creation - iteration  232  of  983
# Flows maps creation - iteration  233  of  983
# Flows maps creation - iteration  234  of  983
# Flows maps creation - iteration  235  of  983
# Flows maps creation - iteration  236  of  983
# Flows maps creation - iteration  237  of  983
# Flows maps creation - iteration  238  of  983
# Flows maps creation - iteration  239  of  983
# Flows maps creation - iteration  240  of  983
# Flows maps creation - iteration  241  of  983
# Flows maps creation - iteration  242  of  983
# Flows maps creation - iteration  243  of  983
# Flows maps creation - iteration  244  of  983
# Flows maps creation - iteration  245  of  983
# Flows maps creation - iteration  246  of  983
# Flows maps creation - iteration  247  of  983
# Flows maps creation - iteration  248  of  983
# Flows maps creation - iteration  249  of  983
# Flows maps creation - iteration  250  of  983
# Flows maps creation - iteration  251  of  983
# Flows maps creation - iteration  252  of  983
# Flows maps creation - iteration  253  of  983
# Flows maps creation - iteration  254  of  983
# Flows maps creation - iteration  255  of  983
# Flows maps creation - iteration  256  of  983
# Flows maps creation - iteration  257  of  983
# Flows maps creation - iteration  258  of  983
# Flows maps creation - iteration  259  of  983
# Flows maps creation - iteration  260  of  983
# Flows maps creation - iteration  261  of  983
# Flows maps creation - iteration  262  of  983
# Flows maps creation - iteration  263  of  983
# Flows maps creation - iteration  264  of  983
# Flows maps creation - iteration  265  of  983
# Flows maps creation - iteration  266  of  983
# Flows maps creation - iteration  267  of  983
# Flows maps creation - iteration  268  of  983
# Flows maps creation - iteration  269  of  983
# Flows maps creation - iteration  270  of  983
# Flows maps creation - iteration  271  of  983
# Flows maps creation - iteration  272  of  983
# Flows maps creation - iteration  273  of  983
# Flows maps creation - iteration  274  of  983
# Flows maps creation - iteration  275  of  983
# Flows maps creation - iteration  276  of  983
# Flows maps creation - iteration  277  of  983
# Flows maps creation - iteration  278  of  983
# Flows maps creation - iteration  279  of  983
# Flows maps creation - iteration  280  of  983
# Flows maps creation - iteration  281  of  983
# Flows maps creation - iteration  282  of  983
# Flows maps creation - iteration  283  of  983
# Flows maps creation - iteration  284  of  983
# Flows maps creation - iteration  285  of  983
# Flows maps creation - iteration  286  of  983
# Flows maps creation - iteration  287  of  983
# Flows maps creation - iteration  288  of  983
# Flows maps creation - iteration  289  of  983
# Flows maps creation - iteration  290  of  983
# Flows maps creation - iteration  291  of  983
# Flows maps creation - iteration  292  of  983
# Flows maps creation - iteration  293  of  983
# Flows maps creation - iteration  294  of  983
# Flows maps creation - iteration  295  of  983
# Flows maps creation - iteration  296  of  983
# Flows maps creation - iteration  297  of  983
# Flows maps creation - iteration  298  of  983
# Flows maps creation - iteration  299  of  983
# Flows maps creation - iteration  300  of  983
# Flows maps creation - iteration  301  of  983
# Flows maps creation - iteration  302  of  983
# Flows maps creation - iteration  303  of  983
# Flows maps creation - iteration  304  of  983
# Flows maps creation - iteration  305  of  983
# Flows maps creation - iteration  306  of  983
# Flows maps creation - iteration  307  of  983
# Flows maps creation - iteration  308  of  983
# Flows maps creation - iteration  309  of  983
# Flows maps creation - iteration  310  of  983
# Flows maps creation - iteration  311  of  983
# Flows maps creation - iteration  312  of  983
# Flows maps creation - iteration  313  of  983
# Flows maps creation - iteration  314  of  983
# Flows maps creation - iteration  315  of  983
# Flows maps creation - iteration  316  of  983
# Flows maps creation - iteration  317  of  983
# Flows maps creation - iteration  318  of  983
# Flows maps creation - iteration  319  of  983
# Flows maps creation - iteration  320  of  983
# Flows maps creation - iteration  321  of  983
# Flows maps creation - iteration  322  of  983
# Flows maps creation - iteration  323  of  983
# Flows maps creation - iteration  324  of  983
# Flows maps creation - iteration  325  of  983
# Flows maps creation - iteration  326  of  983
# Flows maps creation - iteration  327  of  983
# Flows maps creation - iteration  328  of  983
# Flows maps creation - iteration  329  of  983
# Flows maps creation - iteration  330  of  983
# Flows maps creation - iteration  331  of  983
# Flows maps creation - iteration  332  of  983
# Flows maps creation - iteration  333  of  983
# Flows maps creation - iteration  334  of  983
# Flows maps creation - iteration  335  of  983
# Flows maps creation - iteration  336  of  983
# Flows maps creation - iteration  337  of  983
# Flows maps creation - iteration  338  of  983
# Flows maps creation - iteration  339  of  983
# Flows maps creation - iteration  340  of  983
# Flows maps creation - iteration  341  of  983
# Flows maps creation - iteration  342  of  983
# Flows maps creation - iteration  343  of  983
# Flows maps creation - iteration  344  of  983
# Flows maps creation - iteration  345  of  983
# Flows maps creation - iteration  346  of  983
# Flows maps creation - iteration  347  of  983
# Flows maps creation - iteration  348  of  983
# Flows maps creation - iteration  349  of  983
# Flows maps creation - iteration  350  of  983
# Flows maps creation - iteration  351  of  983
# Flows maps creation - iteration  352  of  983
# Flows maps creation - iteration  353  of  983
# Flows maps creation - iteration  354  of  983
# Flows maps creation - iteration  355  of  983
# Flows maps creation - iteration  356  of  983
# Flows maps creation - iteration  357  of  983
# Flows maps creation - iteration  358  of  983
# Flows maps creation - iteration  359  of  983
# Flows maps creation - iteration  360  of  983
# Flows maps creation - iteration  361  of  983
# Flows maps creation - iteration  362  of  983
# Flows maps creation - iteration  363  of  983
# Flows maps creation - iteration  364  of  983
# Flows maps creation - iteration  365  of  983
# Flows maps creation - iteration  366  of  983
# Flows maps creation - iteration  367  of  983
# Flows maps creation - iteration  368  of  983
# Flows maps creation - iteration  369  of  983
# Flows maps creation - iteration  370  of  983
# Flows maps creation - iteration  371  of  983
# Flows maps creation - iteration  372  of  983
# Flows maps creation - iteration  373  of  983
# Flows maps creation - iteration  374  of  983
# Flows maps creation - iteration  375  of  983
# Flows maps creation - iteration  376  of  983
# Flows maps creation - iteration  377  of  983
# Flows maps creation - iteration  378  of  983
# Flows maps creation - iteration  379  of  983
# Flows maps creation - iteration  380  of  983
# Flows maps creation - iteration  381  of  983
# Flows maps creation - iteration  382  of  983
# Flows maps creation - iteration  383  of  983
# Flows maps creation - iteration  384  of  983
# Flows maps creation - iteration  385  of  983
# Flows maps creation - iteration  386  of  983
# Flows maps creation - iteration  387  of  983
# Flows maps creation - iteration  388  of  983
# Flows maps creation - iteration  389  of  983
# Flows maps creation - iteration  390  of  983
# Flows maps creation - iteration  391  of  983
# Flows maps creation - iteration  392  of  983
# Flows maps creation - iteration  393  of  983
# Flows maps creation - iteration  394  of  983
# Flows maps creation - iteration  395  of  983
# Flows maps creation - iteration  396  of  983
# Flows maps creation - iteration  397  of  983
# Flows maps creation - iteration  398  of  983
# Flows maps creation - iteration  399  of  983
# Flows maps creation - iteration  400  of  983
# Flows maps creation - iteration  401  of  983
# Flows maps creation - iteration  402  of  983
# Flows maps creation - iteration  403  of  983
# Flows maps creation - iteration  404  of  983
# Flows maps creation - iteration  405  of  983
# Flows maps creation - iteration  406  of  983
# Flows maps creation - iteration  407  of  983
# Flows maps creation - iteration  408  of  983
# Flows maps creation - iteration  409  of  983
# Flows maps creation - iteration  410  of  983
# Flows maps creation - iteration  411  of  983
# Flows maps creation - iteration  412  of  983
# Flows maps creation - iteration  413  of  983
# Flows maps creation - iteration  414  of  983
# Flows maps creation - iteration  415  of  983
# Flows maps creation - iteration  416  of  983
# Flows maps creation - iteration  417  of  983
# Flows maps creation - iteration  418  of  983
# Flows maps creation - iteration  419  of  983
# Flows maps creation - iteration  420  of  983
# Flows maps creation - iteration  421  of  983
# Flows maps creation - iteration  422  of  983
# Flows maps creation - iteration  423  of  983
# Flows maps creation - iteration  424  of  983
# Flows maps creation - iteration  425  of  983
# Flows maps creation - iteration  426  of  983
# Flows maps creation - iteration  427  of  983
# Flows maps creation - iteration  428  of  983
# Flows maps creation - iteration  429  of  983
# Flows maps creation - iteration  430  of  983
# Flows maps creation - iteration  431  of  983
# Flows maps creation - iteration  432  of  983
# Flows maps creation - iteration  433  of  983
# Flows maps creation - iteration  434  of  983
# Flows maps creation - iteration  435  of  983
# Flows maps creation - iteration  436  of  983
# Flows maps creation - iteration  437  of  983
# Flows maps creation - iteration  438  of  983
# Flows maps creation - iteration  439  of  983
# Flows maps creation - iteration  440  of  983
# Flows maps creation - iteration  441  of  983
# Flows maps creation - iteration  442  of  983
# Flows maps creation - iteration  443  of  983
# Flows maps creation - iteration  444  of  983
# Flows maps creation - iteration  445  of  983
# Flows maps creation - iteration  446  of  983
# Flows maps creation - iteration  447  of  983
# Flows maps creation - iteration  448  of  983
# Flows maps creation - iteration  449  of  983
# Flows maps creation - iteration  450  of  983
# Flows maps creation - iteration  451  of  983
# Flows maps creation - iteration  452  of  983
# Flows maps creation - iteration  453  of  983
# Flows maps creation - iteration  454  of  983
# Flows maps creation - iteration  455  of  983
# Flows maps creation - iteration  456  of  983
# Flows maps creation - iteration  457  of  983
# Flows maps creation - iteration  458  of  983
# Flows maps creation - iteration  459  of  983
# Flows maps creation - iteration  460  of  983
# Flows maps creation - iteration  461  of  983
# Flows maps creation - iteration  462  of  983
# Flows maps creation - iteration  463  of  983
# Flows maps creation - iteration  464  of  983
# Flows maps creation - iteration  465  of  983
# Flows maps creation - iteration  466  of  983
# Flows maps creation - iteration  467  of  983
# Flows maps creation - iteration  468  of  983
# Flows maps creation - iteration  469  of  983
# Flows maps creation - iteration  470  of  983
# Flows maps creation - iteration  471  of  983
# Flows maps creation - iteration  472  of  983
# Flows maps creation - iteration  473  of  983
# Flows maps creation - iteration  474  of  983
# Flows maps creation - iteration  475  of  983
# Flows maps creation - iteration  476  of  983
# Flows maps creation - iteration  477  of  983
# Flows maps creation - iteration  478  of  983
# Flows maps creation - iteration  479  of  983
# Flows maps creation - iteration  480  of  983
# Flows maps creation - iteration  481  of  983
# Flows maps creation - iteration  482  of  983
# Flows maps creation - iteration  483  of  983
# Flows maps creation - iteration  484  of  983
# Flows maps creation - iteration  485  of  983
# Flows maps creation - iteration  486  of  983
# Flows maps creation - iteration  487  of  983
# Flows maps creation - iteration  488  of  983
# Flows maps creation - iteration  489  of  983
# Flows maps creation - iteration  490  of  983
# Flows maps creation - iteration  491  of  983
# Flows maps creation - iteration  492  of  983
# Flows maps creation - iteration  493  of  983
# Flows maps creation - iteration  494  of  983
# Flows maps creation - iteration  495  of  983
# Flows maps creation - iteration  496  of  983
# Flows maps creation - iteration  497  of  983
# Flows maps creation - iteration  498  of  983
# Flows maps creation - iteration  499  of  983
# Flows maps creation - iteration  500  of  983
# Flows maps creation - iteration  501  of  983
# Flows maps creation - iteration  502  of  983
# Flows maps creation - iteration  503  of  983
# Flows maps creation - iteration  504  of  983
# Flows maps creation - iteration  505  of  983
# Flows maps creation - iteration  506  of  983
# Flows maps creation - iteration  507  of  983
# Flows maps creation - iteration  508  of  983
# Flows maps creation - iteration  509  of  983
# Flows maps creation - iteration  510  of  983
# Flows maps creation - iteration  511  of  983
# Flows maps creation - iteration  512  of  983
# Flows maps creation - iteration  513  of  983
# Flows maps creation - iteration  514  of  983
# Flows maps creation - iteration  515  of  983
# Flows maps creation - iteration  516  of  983
# Flows maps creation - iteration  517  of  983
# Flows maps creation - iteration  518  of  983
# Flows maps creation - iteration  519  of  983
# Flows maps creation - iteration  520  of  983
# Flows maps creation - iteration  521  of  983
# Flows maps creation - iteration  522  of  983
# Flows maps creation - iteration  523  of  983
# Flows maps creation - iteration  524  of  983
# Flows maps creation - iteration  525  of  983
# Flows maps creation - iteration  526  of  983
# Flows maps creation - iteration  527  of  983
# Flows maps creation - iteration  528  of  983
# Flows maps creation - iteration  529  of  983
# Flows maps creation - iteration  530  of  983
# Flows maps creation - iteration  531  of  983
# Flows maps creation - iteration  532  of  983
# Flows maps creation - iteration  533  of  983
# Flows maps creation - iteration  534  of  983
# Flows maps creation - iteration  535  of  983
# Flows maps creation - iteration  536  of  983
# Flows maps creation - iteration  537  of  983
# Flows maps creation - iteration  538  of  983
# Flows maps creation - iteration  539  of  983
# Flows maps creation - iteration  540  of  983
# Flows maps creation - iteration  541  of  983
# Flows maps creation - iteration  542  of  983
# Flows maps creation - iteration  543  of  983
# Flows maps creation - iteration  544  of  983
# Flows maps creation - iteration  545  of  983
# Flows maps creation - iteration  546  of  983
# Flows maps creation - iteration  547  of  983
# Flows maps creation - iteration  548  of  983
# Flows maps creation - iteration  549  of  983
# Flows maps creation - iteration  550  of  983
# Flows maps creation - iteration  551  of  983
# Flows maps creation - iteration  552  of  983
# Flows maps creation - iteration  553  of  983
# Flows maps creation - iteration  554  of  983
# Flows maps creation - iteration  555  of  983
# Flows maps creation - iteration  556  of  983
# Flows maps creation - iteration  557  of  983
# Flows maps creation - iteration  558  of  983
# Flows maps creation - iteration  559  of  983
# Flows maps creation - iteration  560  of  983
# Flows maps creation - iteration  561  of  983
# Flows maps creation - iteration  562  of  983
# Flows maps creation - iteration  563  of  983
# Flows maps creation - iteration  564  of  983
# Flows maps creation - iteration  565  of  983
# Flows maps creation - iteration  566  of  983
# Flows maps creation - iteration  567  of  983
# Flows maps creation - iteration  568  of  983
# Flows maps creation - iteration  569  of  983
# Flows maps creation - iteration  570  of  983
# Flows maps creation - iteration  571  of  983
# Flows maps creation - iteration  572  of  983
# Flows maps creation - iteration  573  of  983
# Flows maps creation - iteration  574  of  983
# Flows maps creation - iteration  575  of  983
# Flows maps creation - iteration  576  of  983
# Flows maps creation - iteration  577  of  983
# Flows maps creation - iteration  578  of  983
# Flows maps creation - iteration  579  of  983
# Flows maps creation - iteration  580  of  983
# Flows maps creation - iteration  581  of  983
# Flows maps creation - iteration  582  of  983
# Flows maps creation - iteration  583  of  983
# Flows maps creation - iteration  584  of  983
# Flows maps creation - iteration  585  of  983
# Flows maps creation - iteration  586  of  983
# Flows maps creation - iteration  587  of  983
# Flows maps creation - iteration  588  of  983
# Flows maps creation - iteration  589  of  983
# Flows maps creation - iteration  590  of  983
# Flows maps creation - iteration  591  of  983
# Flows maps creation - iteration  592  of  983
# Flows maps creation - iteration  593  of  983
# Flows maps creation - iteration  594  of  983
# Flows maps creation - iteration  595  of  983
# Flows maps creation - iteration  596  of  983
# Flows maps creation - iteration  597  of  983
# Flows maps creation - iteration  598  of  983
# Flows maps creation - iteration  599  of  983
# Flows maps creation - iteration  600  of  983
# Flows maps creation - iteration  601  of  983
# Flows maps creation - iteration  602  of  983
# Flows maps creation - iteration  603  of  983
# Flows maps creation - iteration  604  of  983
# Flows maps creation - iteration  605  of  983
# Flows maps creation - iteration  606  of  983
# Flows maps creation - iteration  607  of  983
# Flows maps creation - iteration  608  of  983
# Flows maps creation - iteration  609  of  983
# Flows maps creation - iteration  610  of  983
# Flows maps creation - iteration  611  of  983
# Flows maps creation - iteration  612  of  983
# Flows maps creation - iteration  613  of  983
# Flows maps creation - iteration  614  of  983
# Flows maps creation - iteration  615  of  983
# Flows maps creation - iteration  616  of  983
# Flows maps creation - iteration  617  of  983
# Flows maps creation - iteration  618  of  983
# Flows maps creation - iteration  619  of  983
# Flows maps creation - iteration  620  of  983
# Flows maps creation - iteration  621  of  983
# Flows maps creation - iteration  622  of  983
# Flows maps creation - iteration  623  of  983
# Flows maps creation - iteration  624  of  983
# Flows maps creation - iteration  625  of  983
# Flows maps creation - iteration  626  of  983
# Flows maps creation - iteration  627  of  983
# Flows maps creation - iteration  628  of  983
# Flows maps creation - iteration  629  of  983
# Flows maps creation - iteration  630  of  983
# Flows maps creation - iteration  631  of  983
# Flows maps creation - iteration  632  of  983
# Flows maps creation - iteration  633  of  983
# Flows maps creation - iteration  634  of  983
# Flows maps creation - iteration  635  of  983
# Flows maps creation - iteration  636  of  983
# Flows maps creation - iteration  637  of  983
# Flows maps creation - iteration  638  of  983
# Flows maps creation - iteration  639  of  983
# Flows maps creation - iteration  640  of  983
# Flows maps creation - iteration  641  of  983
# Flows maps creation - iteration  642  of  983
# Flows maps creation - iteration  643  of  983
# Flows maps creation - iteration  644  of  983
# Flows maps creation - iteration  645  of  983
# Flows maps creation - iteration  646  of  983
# Flows maps creation - iteration  647  of  983
# Flows maps creation - iteration  648  of  983
# Flows maps creation - iteration  649  of  983
# Flows maps creation - iteration  650  of  983
# Flows maps creation - iteration  651  of  983
# Flows maps creation - iteration  652  of  983
# Flows maps creation - iteration  653  of  983
# Flows maps creation - iteration  654  of  983
# Flows maps creation - iteration  655  of  983
# Flows maps creation - iteration  656  of  983
# Flows maps creation - iteration  657  of  983
# Flows maps creation - iteration  658  of  983
# Flows maps creation - iteration  659  of  983
# Flows maps creation - iteration  660  of  983
# Flows maps creation - iteration  661  of  983
# Flows maps creation - iteration  662  of  983
# Flows maps creation - iteration  663  of  983
# Flows maps creation - iteration  664  of  983
# Flows maps creation - iteration  665  of  983
# Flows maps creation - iteration  666  of  983
# Flows maps creation - iteration  667  of  983
# Flows maps creation - iteration  668  of  983
# Flows maps creation - iteration  669  of  983
# Flows maps creation - iteration  670  of  983
# Flows maps creation - iteration  671  of  983
# Flows maps creation - iteration  672  of  983
# Flows maps creation - iteration  673  of  983
# Flows maps creation - iteration  674  of  983
# Flows maps creation - iteration  675  of  983
# Flows maps creation - iteration  676  of  983
# Flows maps creation - iteration  677  of  983
# Flows maps creation - iteration  678  of  983
# Flows maps creation - iteration  679  of  983
# Flows maps creation - iteration  680  of  983
# Flows maps creation - iteration  681  of  983
# Flows maps creation - iteration  682  of  983
# Flows maps creation - iteration  683  of  983
# Flows maps creation - iteration  684  of  983
# Flows maps creation - iteration  685  of  983
# Flows maps creation - iteration  686  of  983
# Flows maps creation - iteration  687  of  983
# Flows maps creation - iteration  688  of  983
# Flows maps creation - iteration  689  of  983
# Flows maps creation - iteration  690  of  983
# Flows maps creation - iteration  691  of  983
# Flows maps creation - iteration  692  of  983
# Flows maps creation - iteration  693  of  983
# Flows maps creation - iteration  694  of  983
# Flows maps creation - iteration  695  of  983
# Flows maps creation - iteration  696  of  983
# Flows maps creation - iteration  697  of  983
# Flows maps creation - iteration  698  of  983
# Flows maps creation - iteration  699  of  983
# Flows maps creation - iteration  700  of  983
# Flows maps creation - iteration  701  of  983
# Flows maps creation - iteration  702  of  983
# Flows maps creation - iteration  703  of  983
# Flows maps creation - iteration  704  of  983
# Flows maps creation - iteration  705  of  983
# Flows maps creation - iteration  706  of  983
# Flows maps creation - iteration  707  of  983
# Flows maps creation - iteration  708  of  983
# Flows maps creation - iteration  709  of  983
# Flows maps creation - iteration  710  of  983
# Flows maps creation - iteration  711  of  983
# Flows maps creation - iteration  712  of  983
# Flows maps creation - iteration  713  of  983
# Flows maps creation - iteration  714  of  983
# Flows maps creation - iteration  715  of  983
# Flows maps creation - iteration  716  of  983
# Flows maps creation - iteration  717  of  983
# Flows maps creation - iteration  718  of  983
# Flows maps creation - iteration  719  of  983
# Flows maps creation - iteration  720  of  983
# Flows maps creation - iteration  721  of  983
# Flows maps creation - iteration  722  of  983
# Flows maps creation - iteration  723  of  983
# Flows maps creation - iteration  724  of  983
# Flows maps creation - iteration  725  of  983
# Flows maps creation - iteration  726  of  983
# Flows maps creation - iteration  727  of  983
# Flows maps creation - iteration  728  of  983
# Flows maps creation - iteration  729  of  983
# Flows maps creation - iteration  730  of  983
# Flows maps creation - iteration  731  of  983
# Flows maps creation - iteration  732  of  983
# Flows maps creation - iteration  733  of  983
# Flows maps creation - iteration  734  of  983
# Flows maps creation - iteration  735  of  983
# Flows maps creation - iteration  736  of  983
# Flows maps creation - iteration  737  of  983
# Flows maps creation - iteration  738  of  983
# Flows maps creation - iteration  739  of  983
# Flows maps creation - iteration  740  of  983
# Flows maps creation - iteration  741  of  983
# Flows maps creation - iteration  742  of  983
# Flows maps creation - iteration  743  of  983
# Flows maps creation - iteration  744  of  983
# Flows maps creation - iteration  745  of  983
# Flows maps creation - iteration  746  of  983
# Flows maps creation - iteration  747  of  983
# Flows maps creation - iteration  748  of  983
# Flows maps creation - iteration  749  of  983
# Flows maps creation - iteration  750  of  983
# Flows maps creation - iteration  751  of  983
# Flows maps creation - iteration  752  of  983
# Flows maps creation - iteration  753  of  983
# Flows maps creation - iteration  754  of  983
# Flows maps creation - iteration  755  of  983
# Flows maps creation - iteration  756  of  983
# Flows maps creation - iteration  757  of  983
# Flows maps creation - iteration  758  of  983
# Flows maps creation - iteration  759  of  983
# Flows maps creation - iteration  760  of  983
# Flows maps creation - iteration  761  of  983
# Flows maps creation - iteration  762  of  983
# Flows maps creation - iteration  763  of  983
# Flows maps creation - iteration  764  of  983
# Flows maps creation - iteration  765  of  983
# Flows maps creation - iteration  766  of  983
# Flows maps creation - iteration  767  of  983
# Flows maps creation - iteration  768  of  983
# Flows maps creation - iteration  769  of  983
# Flows maps creation - iteration  770  of  983
# Flows maps creation - iteration  771  of  983
# Flows maps creation - iteration  772  of  983
# Flows maps creation - iteration  773  of  983
# Flows maps creation - iteration  774  of  983
# Flows maps creation - iteration  775  of  983
# Flows maps creation - iteration  776  of  983
# Flows maps creation - iteration  777  of  983
# Flows maps creation - iteration  778  of  983
# Flows maps creation - iteration  779  of  983
# Flows maps creation - iteration  780  of  983
# Flows maps creation - iteration  781  of  983
# Flows maps creation - iteration  782  of  983
# Flows maps creation - iteration  783  of  983
# Flows maps creation - iteration  784  of  983
# Flows maps creation - iteration  785  of  983
# Flows maps creation - iteration  786  of  983
# Flows maps creation - iteration  787  of  983
# Flows maps creation - iteration  788  of  983
# Flows maps creation - iteration  789  of  983
# Flows maps creation - iteration  790  of  983
# Flows maps creation - iteration  791  of  983
# Flows maps creation - iteration  792  of  983
# Flows maps creation - iteration  793  of  983
# Flows maps creation - iteration  794  of  983
# Flows maps creation - iteration  795  of  983
# Flows maps creation - iteration  796  of  983
# Flows maps creation - iteration  797  of  983
# Flows maps creation - iteration  798  of  983
# Flows maps creation - iteration  799  of  983
# Flows maps creation - iteration  800  of  983
# Flows maps creation - iteration  801  of  983
# Flows maps creation - iteration  802  of  983
# Flows maps creation - iteration  803  of  983
# Flows maps creation - iteration  804  of  983
# Flows maps creation - iteration  805  of  983
# Flows maps creation - iteration  806  of  983
# Flows maps creation - iteration  807  of  983
# Flows maps creation - iteration  808  of  983
# Flows maps creation - iteration  809  of  983
# Flows maps creation - iteration  810  of  983
# Flows maps creation - iteration  811  of  983
# Flows maps creation - iteration  812  of  983
# Flows maps creation - iteration  813  of  983
# Flows maps creation - iteration  814  of  983
# Flows maps creation - iteration  815  of  983
# Flows maps creation - iteration  816  of  983
# Flows maps creation - iteration  817  of  983
# Flows maps creation - iteration  818  of  983
# Flows maps creation - iteration  819  of  983
# Flows maps creation - iteration  820  of  983
# Flows maps creation - iteration  821  of  983
# Flows maps creation - iteration  822  of  983
# Flows maps creation - iteration  823  of  983
# Flows maps creation - iteration  824  of  983
# Flows maps creation - iteration  825  of  983
# Flows maps creation - iteration  826  of  983
# Flows maps creation - iteration  827  of  983
# Flows maps creation - iteration  828  of  983
# Flows maps creation - iteration  829  of  983
# Flows maps creation - iteration  830  of  983
# Flows maps creation - iteration  831  of  983
# Flows maps creation - iteration  832  of  983
# Flows maps creation - iteration  833  of  983
# Flows maps creation - iteration  834  of  983
# Flows maps creation - iteration  835  of  983
# Flows maps creation - iteration  836  of  983
# Flows maps creation - iteration  837  of  983
# Flows maps creation - iteration  838  of  983
# Flows maps creation - iteration  839  of  983
# Flows maps creation - iteration  840  of  983
# Flows maps creation - iteration  841  of  983
# Flows maps creation - iteration  842  of  983
# Flows maps creation - iteration  843  of  983
# Flows maps creation - iteration  844  of  983
# Flows maps creation - iteration  845  of  983
# Flows maps creation - iteration  846  of  983
# Flows maps creation - iteration  847  of  983
# Flows maps creation - iteration  848  of  983
# Flows maps creation - iteration  849  of  983
# Flows maps creation - iteration  850  of  983
# Flows maps creation - iteration  851  of  983
# Flows maps creation - iteration  852  of  983
# Flows maps creation - iteration  853  of  983
# Flows maps creation - iteration  854  of  983
# Flows maps creation - iteration  855  of  983
# Flows maps creation - iteration  856  of  983
# Flows maps creation - iteration  857  of  983
# Flows maps creation - iteration  858  of  983
# Flows maps creation - iteration  859  of  983
# Flows maps creation - iteration  860  of  983
# Flows maps creation - iteration  861  of  983
# Flows maps creation - iteration  862  of  983
# Flows maps creation - iteration  863  of  983
# Flows maps creation - iteration  864  of  983
# Flows maps creation - iteration  865  of  983
# Flows maps creation - iteration  866  of  983
# Flows maps creation - iteration  867  of  983
# Flows maps creation - iteration  868  of  983
# Flows maps creation - iteration  869  of  983
# Flows maps creation - iteration  870  of  983
# Flows maps creation - iteration  871  of  983
# Flows maps creation - iteration  872  of  983
# Flows maps creation - iteration  873  of  983
# Flows maps creation - iteration  874  of  983
# Flows maps creation - iteration  875  of  983
# Flows maps creation - iteration  876  of  983
# Flows maps creation - iteration  877  of  983
# Flows maps creation - iteration  878  of  983
# Flows maps creation - iteration  879  of  983
# Flows maps creation - iteration  880  of  983
# Flows maps creation - iteration  881  of  983
# Flows maps creation - iteration  882  of  983
# Flows maps creation - iteration  883  of  983
# Flows maps creation - iteration  884  of  983
# Flows maps creation - iteration  885  of  983
# Flows maps creation - iteration  886  of  983
# Flows maps creation - iteration  887  of  983
# Flows maps creation - iteration  888  of  983
# Flows maps creation - iteration  889  of  983
# Flows maps creation - iteration  890  of  983
# Flows maps creation - iteration  891  of  983
# Flows maps creation - iteration  892  of  983
# Flows maps creation - iteration  893  of  983
# Flows maps creation - iteration  894  of  983
# Flows maps creation - iteration  895  of  983
# Flows maps creation - iteration  896  of  983
# Flows maps creation - iteration  897  of  983
# Flows maps creation - iteration  898  of  983
# Flows maps creation - iteration  899  of  983
# Flows maps creation - iteration  900  of  983
# Flows maps creation - iteration  901  of  983
# Flows maps creation - iteration  902  of  983
# Flows maps creation - iteration  903  of  983
# Flows maps creation - iteration  904  of  983
# Flows maps creation - iteration  905  of  983
# Flows maps creation - iteration  906  of  983
# Flows maps creation - iteration  907  of  983
# Flows maps creation - iteration  908  of  983
# Flows maps creation - iteration  909  of  983
# Flows maps creation - iteration  910  of  983
# Flows maps creation - iteration  911  of  983
# Flows maps creation - iteration  912  of  983
# Flows maps creation - iteration  913  of  983
# Flows maps creation - iteration  914  of  983
# Flows maps creation - iteration  915  of  983
# Flows maps creation - iteration  916  of  983
# Flows maps creation - iteration  917  of  983
# Flows maps creation - iteration  918  of  983
# Flows maps creation - iteration  919  of  983
# Flows maps creation - iteration  920  of  983
# Flows maps creation - iteration  921  of  983
# Flows maps creation - iteration  922  of  983
# Flows maps creation - iteration  923  of  983
# Flows maps creation - iteration  924  of  983
# Flows maps creation - iteration  925  of  983
# Flows maps creation - iteration  926  of  983
# Flows maps creation - iteration  927  of  983
# Flows maps creation - iteration  928  of  983
# Flows maps creation - iteration  929  of  983
# Flows maps creation - iteration  930  of  983
# Flows maps creation - iteration  931  of  983
# Flows maps creation - iteration  932  of  983
# Flows maps creation - iteration  933  of  983
# Flows maps creation - iteration  934  of  983
# Flows maps creation - iteration  935  of  983
# Flows maps creation - iteration  936  of  983
# Flows maps creation - iteration  937  of  983
# Flows maps creation - iteration  938  of  983
# Flows maps creation - iteration  939  of  983
# Flows maps creation - iteration  940  of  983
# Flows maps creation - iteration  941  of  983
# Flows maps creation - iteration  942  of  983
# Flows maps creation - iteration  943  of  983
# Flows maps creation - iteration  944  of  983
# Flows maps creation - iteration  945  of  983
# Flows maps creation - iteration  946  of  983
# Flows maps creation - iteration  947  of  983
# Flows maps creation - iteration  948  of  983
# Flows maps creation - iteration  949  of  983
# Flows maps creation - iteration  950  of  983
# Flows maps creation - iteration  951  of  983
# Flows maps creation - iteration  952  of  983
# Flows maps creation - iteration  953  of  983
# Flows maps creation - iteration  954  of  983
# Flows maps creation - iteration  955  of  983
# Flows maps creation - iteration  956  of  983
# Flows maps creation - iteration  957  of  983
# Flows maps creation - iteration  958  of  983
# Flows maps creation - iteration  959  of  983
# Flows maps creation - iteration  960  of  983
# Flows maps creation - iteration  961  of  983
# Flows maps creation - iteration  962  of  983
# Flows maps creation - iteration  963  of  983
# Flows maps creation - iteration  964  of  983
# Flows maps creation - iteration  965  of  983
# Flows maps creation - iteration  966  of  983
# Flows maps creation - iteration  967  of  983
# Flows maps creation - iteration  968  of  983
# Flows maps creation - iteration  969  of  983
# Flows maps creation - iteration  970  of  983
# Flows maps creation - iteration  971  of  983
# Flows maps creation - iteration  972  of  983
# Flows maps creation - iteration  973  of  983
# Flows maps creation - iteration  974  of  983
# Flows maps creation - iteration  975  of  983
# Flows maps creation - iteration  976  of  983
# Flows maps creation - iteration  977  of  983
# Flows maps creation - iteration  978  of  983
# Flows maps creation - iteration  979  of  983
# Flows maps creation - iteration  980  of  983
# Flows maps creation - iteration  981  of  983
# Flows maps creation - iteration  982  of  983
# Flows maps creation - iteration  983  of  983

# %%
X

# %%
ox.save_graph_shapefile(X, filepath='Flows_shp')
# Out:
# /Users/pinlyu/opt/anaconda3/lib/python3.9/site-packages/osmnx/io.py:87: UserWarning: The `save_graph_shapefile` function is deprecated and will be removed in a future release. Instead, use the `save_graph_geopackage` function to save graphs as GeoPackage files for subsequent GIS analysis.
#   warnings.warn(
# /Users/pinlyu/opt/anaconda3/lib/python3.9/site-packages/osmnx/io.py:114: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_nodes.to_file(filepath_nodes, driver="ESRI Shapefile", index=True, encoding=encoding)

# %%
ox.save_graph_geopackage(X, filepath='Flows.gpkg')

# %%
gdf1 = gpd.read_file('data/ESRI/MSOA_2011_London_gen_MHW.shp')
gdf1 = gdf1.to_crs('EPSG: 4326')
gdf1['geometry'] = gdf1['geometry'].centroid
gdf1 = gdf1[['geometry']]

def calc_shortest_paths_ODs_osm(zones_centroids, network):
    list_of_ODs = []
    for c in zones_centroids.geometry:
        graph_clostest_node = ox.nearest_nodes(network, c.x, c.y, return_dist=False)
        list_of_ODs.append(graph_clostest_node)
    return list_of_ODs

Zone_nodes1 = gpd.read_file('data/OXF_MSOA_centroids_WGS84.shp')
Case_Study_Zones1 = ['London, UK']
    # Case_Study_Zones = ['Oxford'] # Smaller network for test purposes

X1 = ox.graph_from_place(Case_Study_Zones1, network_type='drive')
X1 = X1.to_undirected()

def calc_shortest_paths_ODs_osm(zones_centroids, network):
    list_of_ODs = []
    for c in zones_centroids.geometry:
        graph_clostest_node = ox.nearest_nodes(network, c.x, c.y, return_dist=False)
        list_of_ODs.append(graph_clostest_node)
    return list_of_ODs

# Convert GeoDataFrame to suitable format for calc_shortest_paths_ODs_osm function
OD_list1= calc_shortest_paths_ODs_osm(Zone_nodes1, X1)

Flows1 = []
flows_output_keys1 = ['data/populationretailRij_roads_2011_10.csv',
                     'data/populationretailRij_bus_2011_10.csv',
                     'data/populationretailRij_roads_2011_20.csv',
                     'data/populationretailRij_bus_2011_20.csv',
                     'data/populationretailRij_roads_2011_30.csv', 
                     'data/populationretailRij_bus_2011_30.csv',
                     'data/populationretailRij_roads_2011_40.csv',
                     'data/populationretailRij_bus_2011_40.csv',
                     'data/populationretailRij_roads_2011_50.csv',
                     'data/populationretailRij_bus_2011_50.csv',]

for kk, flows_output_key in enumerate(flows_output_keys1):
        Flows1.append(pd.read_csv(flows_output_key, header=None))

        # Initialise weights to 0:
        for source, target in X1.edges():
            X1[source][target][0]["Flows_" + str(kk)] = 0

TOT_count1 = len(OD_list1)
    # print(OD_list)

for n, i in enumerate(OD_list1):
    print("Flows maps creation - iteration ", n+1, " of ", TOT_count1)
    sssp_paths1 = nx.single_source_dijkstra_path(X1, i, weight='length') 
    for m, j in enumerate(OD_list1):
        for cc in range(len(Flows1)):
            if m >= Flows1[cc].shape[1]:
                continue  # Skip if m exceeds the number of columns in Flows[cc]
            
            shortest_path1= sssp_paths1[j] 
            path_edges1 = zip(shortest_path1, shortest_path1[1:])

            for edge in list(path_edges1):
                X1[edge[0]][edge[1]][0]["Flows_" + str(cc)] += Flows1[cc].iloc[n, m]
# Out:
# /var/folders/63/l2ny8d3j1rl_k0h8ghjdkflm0000gn/T/ipykernel_3219/157862635.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf1['geometry'] = gdf1['geometry'].centroid
# Flows maps creation - iteration  1  of  983
# Flows maps creation - iteration  2  of  983
# Flows maps creation - iteration  3  of  983
# Flows maps creation - iteration  4  of  983
# Flows maps creation - iteration  5  of  983
# Flows maps creation - iteration  6  of  983
# Flows maps creation - iteration  7  of  983
# Flows maps creation - iteration  8  of  983
# Flows maps creation - iteration  9  of  983
# Flows maps creation - iteration  10  of  983
# Flows maps creation - iteration  11  of  983
# Flows maps creation - iteration  12  of  983
# Flows maps creation - iteration  13  of  983
# Flows maps creation - iteration  14  of  983
# Flows maps creation - iteration  15  of  983
# Flows maps creation - iteration  16  of  983
# Flows maps creation - iteration  17  of  983
# Flows maps creation - iteration  18  of  983
# Flows maps creation - iteration  19  of  983
# Flows maps creation - iteration  20  of  983
# Flows maps creation - iteration  21  of  983
# Flows maps creation - iteration  22  of  983
# Flows maps creation - iteration  23  of  983
# Flows maps creation - iteration  24  of  983
# Flows maps creation - iteration  25  of  983
# Flows maps creation - iteration  26  of  983
# Flows maps creation - iteration  27  of  983
# Flows maps creation - iteration  28  of  983
# Flows maps creation - iteration  29  of  983
# Flows maps creation - iteration  30  of  983
# Flows maps creation - iteration  31  of  983
# Flows maps creation - iteration  32  of  983
# Flows maps creation - iteration  33  of  983
# Flows maps creation - iteration  34  of  983
# Flows maps creation - iteration  35  of  983
# Flows maps creation - iteration  36  of  983
# Flows maps creation - iteration  37  of  983
# Flows maps creation - iteration  38  of  983
# Flows maps creation - iteration  39  of  983
# Flows maps creation - iteration  40  of  983
# Flows maps creation - iteration  41  of  983
# Flows maps creation - iteration  42  of  983
# Flows maps creation - iteration  43  of  983
# Flows maps creation - iteration  44  of  983
# Flows maps creation - iteration  45  of  983
# Flows maps creation - iteration  46  of  983
# Flows maps creation - iteration  47  of  983
# Flows maps creation - iteration  48  of  983
# Flows maps creation - iteration  49  of  983
# Flows maps creation - iteration  50  of  983
# Flows maps creation - iteration  51  of  983
# Flows maps creation - iteration  52  of  983
# Flows maps creation - iteration  53  of  983
# Flows maps creation - iteration  54  of  983
# Flows maps creation - iteration  55  of  983
# Flows maps creation - iteration  56  of  983
# Flows maps creation - iteration  57  of  983
# Flows maps creation - iteration  58  of  983
# Flows maps creation - iteration  59  of  983
# Flows maps creation - iteration  60  of  983
# Flows maps creation - iteration  61  of  983
# Flows maps creation - iteration  62  of  983
# Flows maps creation - iteration  63  of  983
# Flows maps creation - iteration  64  of  983
# Flows maps creation - iteration  65  of  983
# Flows maps creation - iteration  66  of  983
# Flows maps creation - iteration  67  of  983
# Flows maps creation - iteration  68  of  983
# Flows maps creation - iteration  69  of  983
# Flows maps creation - iteration  70  of  983
# Flows maps creation - iteration  71  of  983
# Flows maps creation - iteration  72  of  983
# Flows maps creation - iteration  73  of  983
# Flows maps creation - iteration  74  of  983
# Flows maps creation - iteration  75  of  983
# Flows maps creation - iteration  76  of  983
# Flows maps creation - iteration  77  of  983
# Flows maps creation - iteration  78  of  983
# Flows maps creation - iteration  79  of  983
# Flows maps creation - iteration  80  of  983
# Flows maps creation - iteration  81  of  983
# Flows maps creation - iteration  82  of  983
# Flows maps creation - iteration  83  of  983
# Flows maps creation - iteration  84  of  983
# Flows maps creation - iteration  85  of  983
# Flows maps creation - iteration  86  of  983
# Flows maps creation - iteration  87  of  983
# Flows maps creation - iteration  88  of  983
# Flows maps creation - iteration  89  of  983
# Flows maps creation - iteration  90  of  983
# Flows maps creation - iteration  91  of  983
# Flows maps creation - iteration  92  of  983
# Flows maps creation - iteration  93  of  983
# Flows maps creation - iteration  94  of  983
# Flows maps creation - iteration  95  of  983
# Flows maps creation - iteration  96  of  983
# Flows maps creation - iteration  97  of  983
# Flows maps creation - iteration  98  of  983
# Flows maps creation - iteration  99  of  983
# Flows maps creation - iteration  100  of  983
# Flows maps creation - iteration  101  of  983
# Flows maps creation - iteration  102  of  983
# Flows maps creation - iteration  103  of  983
# Flows maps creation - iteration  104  of  983
# Flows maps creation - iteration  105  of  983
# Flows maps creation - iteration  106  of  983
# Flows maps creation - iteration  107  of  983
# Flows maps creation - iteration  108  of  983
# Flows maps creation - iteration  109  of  983
# Flows maps creation - iteration  110  of  983
# Flows maps creation - iteration  111  of  983
# Flows maps creation - iteration  112  of  983
# Flows maps creation - iteration  113  of  983
# Flows maps creation - iteration  114  of  983
# Flows maps creation - iteration  115  of  983
# Flows maps creation - iteration  116  of  983
# Flows maps creation - iteration  117  of  983
# Flows maps creation - iteration  118  of  983
# Flows maps creation - iteration  119  of  983
# Flows maps creation - iteration  120  of  983
# Flows maps creation - iteration  121  of  983
# Flows maps creation - iteration  122  of  983
# Flows maps creation - iteration  123  of  983
# Flows maps creation - iteration  124  of  983
# Flows maps creation - iteration  125  of  983
# Flows maps creation - iteration  126  of  983
# Flows maps creation - iteration  127  of  983
# Flows maps creation - iteration  128  of  983
# Flows maps creation - iteration  129  of  983
# Flows maps creation - iteration  130  of  983
# Flows maps creation - iteration  131  of  983
# Flows maps creation - iteration  132  of  983
# Flows maps creation - iteration  133  of  983
# Flows maps creation - iteration  134  of  983
# Flows maps creation - iteration  135  of  983
# Flows maps creation - iteration  136  of  983
# Flows maps creation - iteration  137  of  983
# Flows maps creation - iteration  138  of  983
# Flows maps creation - iteration  139  of  983
# Flows maps creation - iteration  140  of  983
# Flows maps creation - iteration  141  of  983
# Flows maps creation - iteration  142  of  983
# Flows maps creation - iteration  143  of  983
# Flows maps creation - iteration  144  of  983
# Flows maps creation - iteration  145  of  983
# Flows maps creation - iteration  146  of  983
# Flows maps creation - iteration  147  of  983
# Flows maps creation - iteration  148  of  983
# Flows maps creation - iteration  149  of  983
# Flows maps creation - iteration  150  of  983
# Flows maps creation - iteration  151  of  983
# Flows maps creation - iteration  152  of  983
# Flows maps creation - iteration  153  of  983
# Flows maps creation - iteration  154  of  983
# Flows maps creation - iteration  155  of  983
# Flows maps creation - iteration  156  of  983
# Flows maps creation - iteration  157  of  983
# Flows maps creation - iteration  158  of  983
# Flows maps creation - iteration  159  of  983
# Flows maps creation - iteration  160  of  983
# Flows maps creation - iteration  161  of  983
# Flows maps creation - iteration  162  of  983
# Flows maps creation - iteration  163  of  983
# Flows maps creation - iteration  164  of  983
# Flows maps creation - iteration  165  of  983
# Flows maps creation - iteration  166  of  983
# Flows maps creation - iteration  167  of  983
# Flows maps creation - iteration  168  of  983
# Flows maps creation - iteration  169  of  983
# Flows maps creation - iteration  170  of  983
# Flows maps creation - iteration  171  of  983
# Flows maps creation - iteration  172  of  983
# Flows maps creation - iteration  173  of  983
# Flows maps creation - iteration  174  of  983
# Flows maps creation - iteration  175  of  983
# Flows maps creation - iteration  176  of  983
# Flows maps creation - iteration  177  of  983
# Flows maps creation - iteration  178  of  983
# Flows maps creation - iteration  179  of  983
# Flows maps creation - iteration  180  of  983
# Flows maps creation - iteration  181  of  983
# Flows maps creation - iteration  182  of  983
# Flows maps creation - iteration  183  of  983
# Flows maps creation - iteration  184  of  983
# Flows maps creation - iteration  185  of  983
# Flows maps creation - iteration  186  of  983
# Flows maps creation - iteration  187  of  983
# Flows maps creation - iteration  188  of  983
# Flows maps creation - iteration  189  of  983
# Flows maps creation - iteration  190  of  983
# Flows maps creation - iteration  191  of  983
# Flows maps creation - iteration  192  of  983
# Flows maps creation - iteration  193  of  983
# Flows maps creation - iteration  194  of  983
# Flows maps creation - iteration  195  of  983
# Flows maps creation - iteration  196  of  983
# Flows maps creation - iteration  197  of  983
# Flows maps creation - iteration  198  of  983
# Flows maps creation - iteration  199  of  983
# Flows maps creation - iteration  200  of  983
# Flows maps creation - iteration  201  of  983
# Flows maps creation - iteration  202  of  983
# Flows maps creation - iteration  203  of  983
# Flows maps creation - iteration  204  of  983
# Flows maps creation - iteration  205  of  983
# Flows maps creation - iteration  206  of  983
# Flows maps creation - iteration  207  of  983
# Flows maps creation - iteration  208  of  983
# Flows maps creation - iteration  209  of  983
# Flows maps creation - iteration  210  of  983
# Flows maps creation - iteration  211  of  983
# Flows maps creation - iteration  212  of  983
# Flows maps creation - iteration  213  of  983
# Flows maps creation - iteration  214  of  983
# Flows maps creation - iteration  215  of  983
# Flows maps creation - iteration  216  of  983
# Flows maps creation - iteration  217  of  983
# Flows maps creation - iteration  218  of  983
# Flows maps creation - iteration  219  of  983
# Flows maps creation - iteration  220  of  983
# Flows maps creation - iteration  221  of  983
# Flows maps creation - iteration  222  of  983
# Flows maps creation - iteration  223  of  983
# Flows maps creation - iteration  224  of  983
# Flows maps creation - iteration  225  of  983
# Flows maps creation - iteration  226  of  983
# Flows maps creation - iteration  227  of  983
# Flows maps creation - iteration  228  of  983
# Flows maps creation - iteration  229  of  983
# Flows maps creation - iteration  230  of  983
# Flows maps creation - iteration  231  of  983
# Flows maps creation - iteration  232  of  983
# Flows maps creation - iteration  233  of  983
# Flows maps creation - iteration  234  of  983
# Flows maps creation - iteration  235  of  983
# Flows maps creation - iteration  236  of  983
# Flows maps creation - iteration  237  of  983
# Flows maps creation - iteration  238  of  983
# Flows maps creation - iteration  239  of  983
# Flows maps creation - iteration  240  of  983
# Flows maps creation - iteration  241  of  983
# Flows maps creation - iteration  242  of  983
# Flows maps creation - iteration  243  of  983
# Flows maps creation - iteration  244  of  983
# Flows maps creation - iteration  245  of  983
# Flows maps creation - iteration  246  of  983
# Flows maps creation - iteration  247  of  983
# Flows maps creation - iteration  248  of  983
# Flows maps creation - iteration  249  of  983
# Flows maps creation - iteration  250  of  983
# Flows maps creation - iteration  251  of  983
# Flows maps creation - iteration  252  of  983
# Flows maps creation - iteration  253  of  983
# Flows maps creation - iteration  254  of  983
# Flows maps creation - iteration  255  of  983
# Flows maps creation - iteration  256  of  983
# Flows maps creation - iteration  257  of  983
# Flows maps creation - iteration  258  of  983
# Flows maps creation - iteration  259  of  983
# Flows maps creation - iteration  260  of  983
# Flows maps creation - iteration  261  of  983
# Flows maps creation - iteration  262  of  983
# Flows maps creation - iteration  263  of  983
# Flows maps creation - iteration  264  of  983
# Flows maps creation - iteration  265  of  983
# Flows maps creation - iteration  266  of  983
# Flows maps creation - iteration  267  of  983
# Flows maps creation - iteration  268  of  983
# Flows maps creation - iteration  269  of  983
# Flows maps creation - iteration  270  of  983
# Flows maps creation - iteration  271  of  983
# Flows maps creation - iteration  272  of  983
# Flows maps creation - iteration  273  of  983
# Flows maps creation - iteration  274  of  983
# Flows maps creation - iteration  275  of  983
# Flows maps creation - iteration  276  of  983
# Flows maps creation - iteration  277  of  983
# Flows maps creation - iteration  278  of  983
# Flows maps creation - iteration  279  of  983
# Flows maps creation - iteration  280  of  983
# Flows maps creation - iteration  281  of  983
# Flows maps creation - iteration  282  of  983
# Flows maps creation - iteration  283  of  983
# Flows maps creation - iteration  284  of  983
# Flows maps creation - iteration  285  of  983
# Flows maps creation - iteration  286  of  983
# Flows maps creation - iteration  287  of  983
# Flows maps creation - iteration  288  of  983
# Flows maps creation - iteration  289  of  983
# Flows maps creation - iteration  290  of  983
# Flows maps creation - iteration  291  of  983
# Flows maps creation - iteration  292  of  983
# Flows maps creation - iteration  293  of  983
# Flows maps creation - iteration  294  of  983
# Flows maps creation - iteration  295  of  983
# Flows maps creation - iteration  296  of  983
# Flows maps creation - iteration  297  of  983
# Flows maps creation - iteration  298  of  983
# Flows maps creation - iteration  299  of  983
# Flows maps creation - iteration  300  of  983
# Flows maps creation - iteration  301  of  983
# Flows maps creation - iteration  302  of  983
# Flows maps creation - iteration  303  of  983
# Flows maps creation - iteration  304  of  983
# Flows maps creation - iteration  305  of  983
# Flows maps creation - iteration  306  of  983
# Flows maps creation - iteration  307  of  983
# Flows maps creation - iteration  308  of  983
# Flows maps creation - iteration  309  of  983
# Flows maps creation - iteration  310  of  983
# Flows maps creation - iteration  311  of  983
# Flows maps creation - iteration  312  of  983
# Flows maps creation - iteration  313  of  983
# Flows maps creation - iteration  314  of  983
# Flows maps creation - iteration  315  of  983
# Flows maps creation - iteration  316  of  983
# Flows maps creation - iteration  317  of  983
# Flows maps creation - iteration  318  of  983
# Flows maps creation - iteration  319  of  983
# Flows maps creation - iteration  320  of  983
# Flows maps creation - iteration  321  of  983
# Flows maps creation - iteration  322  of  983
# Flows maps creation - iteration  323  of  983
# Flows maps creation - iteration  324  of  983
# Flows maps creation - iteration  325  of  983
# Flows maps creation - iteration  326  of  983
# Flows maps creation - iteration  327  of  983
# Flows maps creation - iteration  328  of  983
# Flows maps creation - iteration  329  of  983
# Flows maps creation - iteration  330  of  983
# Flows maps creation - iteration  331  of  983
# Flows maps creation - iteration  332  of  983
# Flows maps creation - iteration  333  of  983
# Flows maps creation - iteration  334  of  983
# Flows maps creation - iteration  335  of  983
# Flows maps creation - iteration  336  of  983
# Flows maps creation - iteration  337  of  983
# Flows maps creation - iteration  338  of  983
# Flows maps creation - iteration  339  of  983
# Flows maps creation - iteration  340  of  983
# Flows maps creation - iteration  341  of  983
# Flows maps creation - iteration  342  of  983
# Flows maps creation - iteration  343  of  983
# Flows maps creation - iteration  344  of  983
# Flows maps creation - iteration  345  of  983
# Flows maps creation - iteration  346  of  983
# Flows maps creation - iteration  347  of  983
# Flows maps creation - iteration  348  of  983
# Flows maps creation - iteration  349  of  983
# Flows maps creation - iteration  350  of  983
# Flows maps creation - iteration  351  of  983
# Flows maps creation - iteration  352  of  983
# Flows maps creation - iteration  353  of  983
# Flows maps creation - iteration  354  of  983
# Flows maps creation - iteration  355  of  983
# Flows maps creation - iteration  356  of  983
# Flows maps creation - iteration  357  of  983
# Flows maps creation - iteration  358  of  983
# Flows maps creation - iteration  359  of  983
# Flows maps creation - iteration  360  of  983
# Flows maps creation - iteration  361  of  983
# Flows maps creation - iteration  362  of  983
# Flows maps creation - iteration  363  of  983
# Flows maps creation - iteration  364  of  983
# Flows maps creation - iteration  365  of  983
# Flows maps creation - iteration  366  of  983
# Flows maps creation - iteration  367  of  983
# Flows maps creation - iteration  368  of  983
# Flows maps creation - iteration  369  of  983
# Flows maps creation - iteration  370  of  983
# Flows maps creation - iteration  371  of  983
# Flows maps creation - iteration  372  of  983
# Flows maps creation - iteration  373  of  983
# Flows maps creation - iteration  374  of  983
# Flows maps creation - iteration  375  of  983
# Flows maps creation - iteration  376  of  983
# Flows maps creation - iteration  377  of  983
# Flows maps creation - iteration  378  of  983
# Flows maps creation - iteration  379  of  983
# Flows maps creation - iteration  380  of  983
# Flows maps creation - iteration  381  of  983
# Flows maps creation - iteration  382  of  983
# Flows maps creation - iteration  383  of  983
# Flows maps creation - iteration  384  of  983
# Flows maps creation - iteration  385  of  983
# Flows maps creation - iteration  386  of  983
# Flows maps creation - iteration  387  of  983
# Flows maps creation - iteration  388  of  983
# Flows maps creation - iteration  389  of  983
# Flows maps creation - iteration  390  of  983
# Flows maps creation - iteration  391  of  983
# Flows maps creation - iteration  392  of  983
# Flows maps creation - iteration  393  of  983
# Flows maps creation - iteration  394  of  983
# Flows maps creation - iteration  395  of  983
# Flows maps creation - iteration  396  of  983
# Flows maps creation - iteration  397  of  983
# Flows maps creation - iteration  398  of  983
# Flows maps creation - iteration  399  of  983
# Flows maps creation - iteration  400  of  983
# Flows maps creation - iteration  401  of  983
# Flows maps creation - iteration  402  of  983
# Flows maps creation - iteration  403  of  983
# Flows maps creation - iteration  404  of  983
# Flows maps creation - iteration  405  of  983
# Flows maps creation - iteration  406  of  983
# Flows maps creation - iteration  407  of  983
# Flows maps creation - iteration  408  of  983
# Flows maps creation - iteration  409  of  983
# Flows maps creation - iteration  410  of  983
# Flows maps creation - iteration  411  of  983
# Flows maps creation - iteration  412  of  983
# Flows maps creation - iteration  413  of  983
# Flows maps creation - iteration  414  of  983
# Flows maps creation - iteration  415  of  983
# Flows maps creation - iteration  416  of  983
# Flows maps creation - iteration  417  of  983
# Flows maps creation - iteration  418  of  983
# Flows maps creation - iteration  419  of  983
# Flows maps creation - iteration  420  of  983
# Flows maps creation - iteration  421  of  983
# Flows maps creation - iteration  422  of  983
# Flows maps creation - iteration  423  of  983
# Flows maps creation - iteration  424  of  983
# Flows maps creation - iteration  425  of  983
# Flows maps creation - iteration  426  of  983
# Flows maps creation - iteration  427  of  983
# Flows maps creation - iteration  428  of  983
# Flows maps creation - iteration  429  of  983
# Flows maps creation - iteration  430  of  983
# Flows maps creation - iteration  431  of  983
# Flows maps creation - iteration  432  of  983
# Flows maps creation - iteration  433  of  983
# Flows maps creation - iteration  434  of  983
# Flows maps creation - iteration  435  of  983
# Flows maps creation - iteration  436  of  983
# Flows maps creation - iteration  437  of  983
# Flows maps creation - iteration  438  of  983
# Flows maps creation - iteration  439  of  983
# Flows maps creation - iteration  440  of  983
# Flows maps creation - iteration  441  of  983
# Flows maps creation - iteration  442  of  983
# Flows maps creation - iteration  443  of  983
# Flows maps creation - iteration  444  of  983
# Flows maps creation - iteration  445  of  983
# Flows maps creation - iteration  446  of  983
# Flows maps creation - iteration  447  of  983
# Flows maps creation - iteration  448  of  983
# Flows maps creation - iteration  449  of  983
# Flows maps creation - iteration  450  of  983
# Flows maps creation - iteration  451  of  983
# Flows maps creation - iteration  452  of  983
# Flows maps creation - iteration  453  of  983
# Flows maps creation - iteration  454  of  983
# Flows maps creation - iteration  455  of  983
# Flows maps creation - iteration  456  of  983
# Flows maps creation - iteration  457  of  983
# Flows maps creation - iteration  458  of  983
# Flows maps creation - iteration  459  of  983
# Flows maps creation - iteration  460  of  983
# Flows maps creation - iteration  461  of  983
# Flows maps creation - iteration  462  of  983
# Flows maps creation - iteration  463  of  983
# Flows maps creation - iteration  464  of  983
# Flows maps creation - iteration  465  of  983
# Flows maps creation - iteration  466  of  983
# Flows maps creation - iteration  467  of  983
# Flows maps creation - iteration  468  of  983
# Flows maps creation - iteration  469  of  983
# Flows maps creation - iteration  470  of  983
# Flows maps creation - iteration  471  of  983
# Flows maps creation - iteration  472  of  983
# Flows maps creation - iteration  473  of  983
# Flows maps creation - iteration  474  of  983
# Flows maps creation - iteration  475  of  983
# Flows maps creation - iteration  476  of  983
# Flows maps creation - iteration  477  of  983
# Flows maps creation - iteration  478  of  983
# Flows maps creation - iteration  479  of  983
# Flows maps creation - iteration  480  of  983
# Flows maps creation - iteration  481  of  983
# Flows maps creation - iteration  482  of  983
# Flows maps creation - iteration  483  of  983
# Flows maps creation - iteration  484  of  983
# Flows maps creation - iteration  485  of  983
# Flows maps creation - iteration  486  of  983
# Flows maps creation - iteration  487  of  983
# Flows maps creation - iteration  488  of  983
# Flows maps creation - iteration  489  of  983
# Flows maps creation - iteration  490  of  983
# Flows maps creation - iteration  491  of  983
# Flows maps creation - iteration  492  of  983
# Flows maps creation - iteration  493  of  983
# Flows maps creation - iteration  494  of  983
# Flows maps creation - iteration  495  of  983
# Flows maps creation - iteration  496  of  983
# Flows maps creation - iteration  497  of  983
# Flows maps creation - iteration  498  of  983
# Flows maps creation - iteration  499  of  983
# Flows maps creation - iteration  500  of  983
# Flows maps creation - iteration  501  of  983
# Flows maps creation - iteration  502  of  983
# Flows maps creation - iteration  503  of  983
# Flows maps creation - iteration  504  of  983
# Flows maps creation - iteration  505  of  983
# Flows maps creation - iteration  506  of  983
# Flows maps creation - iteration  507  of  983
# Flows maps creation - iteration  508  of  983
# Flows maps creation - iteration  509  of  983
# Flows maps creation - iteration  510  of  983
# Flows maps creation - iteration  511  of  983
# Flows maps creation - iteration  512  of  983
# Flows maps creation - iteration  513  of  983
# Flows maps creation - iteration  514  of  983
# Flows maps creation - iteration  515  of  983
# Flows maps creation - iteration  516  of  983
# Flows maps creation - iteration  517  of  983
# Flows maps creation - iteration  518  of  983
# Flows maps creation - iteration  519  of  983
# Flows maps creation - iteration  520  of  983
# Flows maps creation - iteration  521  of  983
# Flows maps creation - iteration  522  of  983
# Flows maps creation - iteration  523  of  983
# Flows maps creation - iteration  524  of  983
# Flows maps creation - iteration  525  of  983
# Flows maps creation - iteration  526  of  983
# Flows maps creation - iteration  527  of  983
# Flows maps creation - iteration  528  of  983
# Flows maps creation - iteration  529  of  983
# Flows maps creation - iteration  530  of  983
# Flows maps creation - iteration  531  of  983
# Flows maps creation - iteration  532  of  983
# Flows maps creation - iteration  533  of  983
# Flows maps creation - iteration  534  of  983
# Flows maps creation - iteration  535  of  983
# Flows maps creation - iteration  536  of  983
# Flows maps creation - iteration  537  of  983
# Flows maps creation - iteration  538  of  983
# Flows maps creation - iteration  539  of  983
# Flows maps creation - iteration  540  of  983
# Flows maps creation - iteration  541  of  983
# Flows maps creation - iteration  542  of  983
# Flows maps creation - iteration  543  of  983
# Flows maps creation - iteration  544  of  983
# Flows maps creation - iteration  545  of  983
# Flows maps creation - iteration  546  of  983
# Flows maps creation - iteration  547  of  983
# Flows maps creation - iteration  548  of  983
# Flows maps creation - iteration  549  of  983
# Flows maps creation - iteration  550  of  983
# Flows maps creation - iteration  551  of  983
# Flows maps creation - iteration  552  of  983
# Flows maps creation - iteration  553  of  983
# Flows maps creation - iteration  554  of  983
# Flows maps creation - iteration  555  of  983
# Flows maps creation - iteration  556  of  983
# Flows maps creation - iteration  557  of  983
# Flows maps creation - iteration  558  of  983
# Flows maps creation - iteration  559  of  983
# Flows maps creation - iteration  560  of  983
# Flows maps creation - iteration  561  of  983
# Flows maps creation - iteration  562  of  983
# Flows maps creation - iteration  563  of  983
# Flows maps creation - iteration  564  of  983
# Flows maps creation - iteration  565  of  983
# Flows maps creation - iteration  566  of  983
# Flows maps creation - iteration  567  of  983
# Flows maps creation - iteration  568  of  983
# Flows maps creation - iteration  569  of  983
# Flows maps creation - iteration  570  of  983
# Flows maps creation - iteration  571  of  983
# Flows maps creation - iteration  572  of  983
# Flows maps creation - iteration  573  of  983
# Flows maps creation - iteration  574  of  983
# Flows maps creation - iteration  575  of  983
# Flows maps creation - iteration  576  of  983
# Flows maps creation - iteration  577  of  983
# Flows maps creation - iteration  578  of  983
# Flows maps creation - iteration  579  of  983
# Flows maps creation - iteration  580  of  983
# Flows maps creation - iteration  581  of  983
# Flows maps creation - iteration  582  of  983
# Flows maps creation - iteration  583  of  983
# Flows maps creation - iteration  584  of  983
# Flows maps creation - iteration  585  of  983
# Flows maps creation - iteration  586  of  983
# Flows maps creation - iteration  587  of  983
# Flows maps creation - iteration  588  of  983
# Flows maps creation - iteration  589  of  983
# Flows maps creation - iteration  590  of  983
# Flows maps creation - iteration  591  of  983
# Flows maps creation - iteration  592  of  983
# Flows maps creation - iteration  593  of  983
# Flows maps creation - iteration  594  of  983
# Flows maps creation - iteration  595  of  983
# Flows maps creation - iteration  596  of  983
# Flows maps creation - iteration  597  of  983
# Flows maps creation - iteration  598  of  983
# Flows maps creation - iteration  599  of  983
# Flows maps creation - iteration  600  of  983
# Flows maps creation - iteration  601  of  983
# Flows maps creation - iteration  602  of  983
# Flows maps creation - iteration  603  of  983
# Flows maps creation - iteration  604  of  983
# Flows maps creation - iteration  605  of  983
# Flows maps creation - iteration  606  of  983
# Flows maps creation - iteration  607  of  983
# Flows maps creation - iteration  608  of  983
# Flows maps creation - iteration  609  of  983
# Flows maps creation - iteration  610  of  983
# Flows maps creation - iteration  611  of  983
# Flows maps creation - iteration  612  of  983
# Flows maps creation - iteration  613  of  983
# Flows maps creation - iteration  614  of  983
# Flows maps creation - iteration  615  of  983
# Flows maps creation - iteration  616  of  983
# Flows maps creation - iteration  617  of  983
# Flows maps creation - iteration  618  of  983
# Flows maps creation - iteration  619  of  983
# Flows maps creation - iteration  620  of  983
# Flows maps creation - iteration  621  of  983
# Flows maps creation - iteration  622  of  983
# Flows maps creation - iteration  623  of  983
# Flows maps creation - iteration  624  of  983
# Flows maps creation - iteration  625  of  983
# Flows maps creation - iteration  626  of  983
# Flows maps creation - iteration  627  of  983
# Flows maps creation - iteration  628  of  983
# Flows maps creation - iteration  629  of  983
# Flows maps creation - iteration  630  of  983
# Flows maps creation - iteration  631  of  983
# Flows maps creation - iteration  632  of  983
# Flows maps creation - iteration  633  of  983
# Flows maps creation - iteration  634  of  983
# Flows maps creation - iteration  635  of  983
# Flows maps creation - iteration  636  of  983
# Flows maps creation - iteration  637  of  983
# Flows maps creation - iteration  638  of  983
# Flows maps creation - iteration  639  of  983
# Flows maps creation - iteration  640  of  983
# Flows maps creation - iteration  641  of  983
# Flows maps creation - iteration  642  of  983
# Flows maps creation - iteration  643  of  983
# Flows maps creation - iteration  644  of  983
# Flows maps creation - iteration  645  of  983
# Flows maps creation - iteration  646  of  983
# Flows maps creation - iteration  647  of  983
# Flows maps creation - iteration  648  of  983
# Flows maps creation - iteration  649  of  983
# Flows maps creation - iteration  650  of  983
# Flows maps creation - iteration  651  of  983
# Flows maps creation - iteration  652  of  983
# Flows maps creation - iteration  653  of  983
# Flows maps creation - iteration  654  of  983
# Flows maps creation - iteration  655  of  983
# Flows maps creation - iteration  656  of  983
# Flows maps creation - iteration  657  of  983
# Flows maps creation - iteration  658  of  983
# Flows maps creation - iteration  659  of  983
# Flows maps creation - iteration  660  of  983
# Flows maps creation - iteration  661  of  983
# Flows maps creation - iteration  662  of  983
# Flows maps creation - iteration  663  of  983
# Flows maps creation - iteration  664  of  983
# Flows maps creation - iteration  665  of  983
# Flows maps creation - iteration  666  of  983
# Flows maps creation - iteration  667  of  983
# Flows maps creation - iteration  668  of  983
# Flows maps creation - iteration  669  of  983
# Flows maps creation - iteration  670  of  983
# Flows maps creation - iteration  671  of  983
# Flows maps creation - iteration  672  of  983
# Flows maps creation - iteration  673  of  983
# Flows maps creation - iteration  674  of  983
# Flows maps creation - iteration  675  of  983
# Flows maps creation - iteration  676  of  983
# Flows maps creation - iteration  677  of  983
# Flows maps creation - iteration  678  of  983
# Flows maps creation - iteration  679  of  983
# Flows maps creation - iteration  680  of  983
# Flows maps creation - iteration  681  of  983
# Flows maps creation - iteration  682  of  983
# Flows maps creation - iteration  683  of  983
# Flows maps creation - iteration  684  of  983
# Flows maps creation - iteration  685  of  983
# Flows maps creation - iteration  686  of  983
# Flows maps creation - iteration  687  of  983
# Flows maps creation - iteration  688  of  983
# Flows maps creation - iteration  689  of  983
# Flows maps creation - iteration  690  of  983
# Flows maps creation - iteration  691  of  983
# Flows maps creation - iteration  692  of  983
# Flows maps creation - iteration  693  of  983
# Flows maps creation - iteration  694  of  983
# Flows maps creation - iteration  695  of  983
# Flows maps creation - iteration  696  of  983
# Flows maps creation - iteration  697  of  983
# Flows maps creation - iteration  698  of  983
# Flows maps creation - iteration  699  of  983
# Flows maps creation - iteration  700  of  983
# Flows maps creation - iteration  701  of  983
# Flows maps creation - iteration  702  of  983
# Flows maps creation - iteration  703  of  983
# Flows maps creation - iteration  704  of  983
# Flows maps creation - iteration  705  of  983
# Flows maps creation - iteration  706  of  983
# Flows maps creation - iteration  707  of  983
# Flows maps creation - iteration  708  of  983
# Flows maps creation - iteration  709  of  983
# Flows maps creation - iteration  710  of  983
# Flows maps creation - iteration  711  of  983
# Flows maps creation - iteration  712  of  983
# Flows maps creation - iteration  713  of  983
# Flows maps creation - iteration  714  of  983
# Flows maps creation - iteration  715  of  983
# Flows maps creation - iteration  716  of  983
# Flows maps creation - iteration  717  of  983
# Flows maps creation - iteration  718  of  983
# Flows maps creation - iteration  719  of  983
# Flows maps creation - iteration  720  of  983
# Flows maps creation - iteration  721  of  983
# Flows maps creation - iteration  722  of  983
# Flows maps creation - iteration  723  of  983
# Flows maps creation - iteration  724  of  983
# Flows maps creation - iteration  725  of  983
# Flows maps creation - iteration  726  of  983
# Flows maps creation - iteration  727  of  983
# Flows maps creation - iteration  728  of  983
# Flows maps creation - iteration  729  of  983
# Flows maps creation - iteration  730  of  983
# Flows maps creation - iteration  731  of  983
# Flows maps creation - iteration  732  of  983
# Flows maps creation - iteration  733  of  983
# Flows maps creation - iteration  734  of  983
# Flows maps creation - iteration  735  of  983
# Flows maps creation - iteration  736  of  983
# Flows maps creation - iteration  737  of  983
# Flows maps creation - iteration  738  of  983
# Flows maps creation - iteration  739  of  983
# Flows maps creation - iteration  740  of  983
# Flows maps creation - iteration  741  of  983
# Flows maps creation - iteration  742  of  983
# Flows maps creation - iteration  743  of  983
# Flows maps creation - iteration  744  of  983
# Flows maps creation - iteration  745  of  983
# Flows maps creation - iteration  746  of  983
# Flows maps creation - iteration  747  of  983
# Flows maps creation - iteration  748  of  983
# Flows maps creation - iteration  749  of  983
# Flows maps creation - iteration  750  of  983
# Flows maps creation - iteration  751  of  983
# Flows maps creation - iteration  752  of  983
# Flows maps creation - iteration  753  of  983
# Flows maps creation - iteration  754  of  983
# Flows maps creation - iteration  755  of  983
# Flows maps creation - iteration  756  of  983
# Flows maps creation - iteration  757  of  983
# Flows maps creation - iteration  758  of  983
# Flows maps creation - iteration  759  of  983
# Flows maps creation - iteration  760  of  983
# Flows maps creation - iteration  761  of  983
# Flows maps creation - iteration  762  of  983
# Flows maps creation - iteration  763  of  983
# Flows maps creation - iteration  764  of  983
# Flows maps creation - iteration  765  of  983
# Flows maps creation - iteration  766  of  983
# Flows maps creation - iteration  767  of  983
# Flows maps creation - iteration  768  of  983
# Flows maps creation - iteration  769  of  983
# Flows maps creation - iteration  770  of  983
# Flows maps creation - iteration  771  of  983
# Flows maps creation - iteration  772  of  983
# Flows maps creation - iteration  773  of  983
# Flows maps creation - iteration  774  of  983
# Flows maps creation - iteration  775  of  983
# Flows maps creation - iteration  776  of  983
# Flows maps creation - iteration  777  of  983
# Flows maps creation - iteration  778  of  983
# Flows maps creation - iteration  779  of  983
# Flows maps creation - iteration  780  of  983
# Flows maps creation - iteration  781  of  983
# Flows maps creation - iteration  782  of  983
# Flows maps creation - iteration  783  of  983
# Flows maps creation - iteration  784  of  983
# Flows maps creation - iteration  785  of  983
# Flows maps creation - iteration  786  of  983
# Flows maps creation - iteration  787  of  983
# Flows maps creation - iteration  788  of  983
# Flows maps creation - iteration  789  of  983
# Flows maps creation - iteration  790  of  983
# Flows maps creation - iteration  791  of  983
# Flows maps creation - iteration  792  of  983
# Flows maps creation - iteration  793  of  983
# Flows maps creation - iteration  794  of  983
# Flows maps creation - iteration  795  of  983
# Flows maps creation - iteration  796  of  983
# Flows maps creation - iteration  797  of  983
# Flows maps creation - iteration  798  of  983
# Flows maps creation - iteration  799  of  983
# Flows maps creation - iteration  800  of  983
# Flows maps creation - iteration  801  of  983
# Flows maps creation - iteration  802  of  983
# Flows maps creation - iteration  803  of  983
# Flows maps creation - iteration  804  of  983
# Flows maps creation - iteration  805  of  983
# Flows maps creation - iteration  806  of  983
# Flows maps creation - iteration  807  of  983
# Flows maps creation - iteration  808  of  983
# Flows maps creation - iteration  809  of  983
# Flows maps creation - iteration  810  of  983
# Flows maps creation - iteration  811  of  983
# Flows maps creation - iteration  812  of  983
# Flows maps creation - iteration  813  of  983
# Flows maps creation - iteration  814  of  983
# Flows maps creation - iteration  815  of  983
# Flows maps creation - iteration  816  of  983
# Flows maps creation - iteration  817  of  983
# Flows maps creation - iteration  818  of  983
# Flows maps creation - iteration  819  of  983
# Flows maps creation - iteration  820  of  983
# Flows maps creation - iteration  821  of  983
# Flows maps creation - iteration  822  of  983
# Flows maps creation - iteration  823  of  983
# Flows maps creation - iteration  824  of  983
# Flows maps creation - iteration  825  of  983
# Flows maps creation - iteration  826  of  983
# Flows maps creation - iteration  827  of  983
# Flows maps creation - iteration  828  of  983
# Flows maps creation - iteration  829  of  983
# Flows maps creation - iteration  830  of  983
# Flows maps creation - iteration  831  of  983
# Flows maps creation - iteration  832  of  983
# Flows maps creation - iteration  833  of  983
# Flows maps creation - iteration  834  of  983
# Flows maps creation - iteration  835  of  983
# Flows maps creation - iteration  836  of  983
# Flows maps creation - iteration  837  of  983
# Flows maps creation - iteration  838  of  983
# Flows maps creation - iteration  839  of  983
# Flows maps creation - iteration  840  of  983
# Flows maps creation - iteration  841  of  983
# Flows maps creation - iteration  842  of  983
# Flows maps creation - iteration  843  of  983
# Flows maps creation - iteration  844  of  983
# Flows maps creation - iteration  845  of  983
# Flows maps creation - iteration  846  of  983
# Flows maps creation - iteration  847  of  983
# Flows maps creation - iteration  848  of  983
# Flows maps creation - iteration  849  of  983
# Flows maps creation - iteration  850  of  983
# Flows maps creation - iteration  851  of  983
# Flows maps creation - iteration  852  of  983
# Flows maps creation - iteration  853  of  983
# Flows maps creation - iteration  854  of  983
# Flows maps creation - iteration  855  of  983
# Flows maps creation - iteration  856  of  983
# Flows maps creation - iteration  857  of  983
# Flows maps creation - iteration  858  of  983
# Flows maps creation - iteration  859  of  983
# Flows maps creation - iteration  860  of  983
# Flows maps creation - iteration  861  of  983
# Flows maps creation - iteration  862  of  983
# Flows maps creation - iteration  863  of  983
# Flows maps creation - iteration  864  of  983
# Flows maps creation - iteration  865  of  983
# Flows maps creation - iteration  866  of  983
# Flows maps creation - iteration  867  of  983
# Flows maps creation - iteration  868  of  983
# Flows maps creation - iteration  869  of  983
# Flows maps creation - iteration  870  of  983
# Flows maps creation - iteration  871  of  983
# Flows maps creation - iteration  872  of  983
# Flows maps creation - iteration  873  of  983
# Flows maps creation - iteration  874  of  983
# Flows maps creation - iteration  875  of  983
# Flows maps creation - iteration  876  of  983
# Flows maps creation - iteration  877  of  983
# Flows maps creation - iteration  878  of  983
# Flows maps creation - iteration  879  of  983
# Flows maps creation - iteration  880  of  983
# Flows maps creation - iteration  881  of  983
# Flows maps creation - iteration  882  of  983
# Flows maps creation - iteration  883  of  983
# Flows maps creation - iteration  884  of  983
# Flows maps creation - iteration  885  of  983
# Flows maps creation - iteration  886  of  983
# Flows maps creation - iteration  887  of  983
# Flows maps creation - iteration  888  of  983
# Flows maps creation - iteration  889  of  983
# Flows maps creation - iteration  890  of  983
# Flows maps creation - iteration  891  of  983
# Flows maps creation - iteration  892  of  983
# Flows maps creation - iteration  893  of  983
# Flows maps creation - iteration  894  of  983
# Flows maps creation - iteration  895  of  983
# Flows maps creation - iteration  896  of  983
# Flows maps creation - iteration  897  of  983
# Flows maps creation - iteration  898  of  983
# Flows maps creation - iteration  899  of  983
# Flows maps creation - iteration  900  of  983
# Flows maps creation - iteration  901  of  983
# Flows maps creation - iteration  902  of  983
# Flows maps creation - iteration  903  of  983
# Flows maps creation - iteration  904  of  983
# Flows maps creation - iteration  905  of  983
# Flows maps creation - iteration  906  of  983
# Flows maps creation - iteration  907  of  983
# Flows maps creation - iteration  908  of  983
# Flows maps creation - iteration  909  of  983
# Flows maps creation - iteration  910  of  983
# Flows maps creation - iteration  911  of  983
# Flows maps creation - iteration  912  of  983
# Flows maps creation - iteration  913  of  983
# Flows maps creation - iteration  914  of  983
# Flows maps creation - iteration  915  of  983
# Flows maps creation - iteration  916  of  983
# Flows maps creation - iteration  917  of  983
# Flows maps creation - iteration  918  of  983
# Flows maps creation - iteration  919  of  983
# Flows maps creation - iteration  920  of  983
# Flows maps creation - iteration  921  of  983
# Flows maps creation - iteration  922  of  983
# Flows maps creation - iteration  923  of  983
# Flows maps creation - iteration  924  of  983
# Flows maps creation - iteration  925  of  983
# Flows maps creation - iteration  926  of  983
# Flows maps creation - iteration  927  of  983
# Flows maps creation - iteration  928  of  983
# Flows maps creation - iteration  929  of  983
# Flows maps creation - iteration  930  of  983
# Flows maps creation - iteration  931  of  983
# Flows maps creation - iteration  932  of  983
# Flows maps creation - iteration  933  of  983
# Flows maps creation - iteration  934  of  983
# Flows maps creation - iteration  935  of  983
# Flows maps creation - iteration  936  of  983
# Flows maps creation - iteration  937  of  983
# Flows maps creation - iteration  938  of  983
# Flows maps creation - iteration  939  of  983
# Flows maps creation - iteration  940  of  983
# Flows maps creation - iteration  941  of  983
# Flows maps creation - iteration  942  of  983
# Flows maps creation - iteration  943  of  983
# Flows maps creation - iteration  944  of  983
# Flows maps creation - iteration  945  of  983
# Flows maps creation - iteration  946  of  983
# Flows maps creation - iteration  947  of  983
# Flows maps creation - iteration  948  of  983
# Flows maps creation - iteration  949  of  983
# Flows maps creation - iteration  950  of  983
# Flows maps creation - iteration  951  of  983
# Flows maps creation - iteration  952  of  983
# Flows maps creation - iteration  953  of  983
# Flows maps creation - iteration  954  of  983
# Flows maps creation - iteration  955  of  983
# Flows maps creation - iteration  956  of  983
# Flows maps creation - iteration  957  of  983
# Flows maps creation - iteration  958  of  983
# Flows maps creation - iteration  959  of  983
# Flows maps creation - iteration  960  of  983
# Flows maps creation - iteration  961  of  983
# Flows maps creation - iteration  962  of  983
# Flows maps creation - iteration  963  of  983
# Flows maps creation - iteration  964  of  983
# Flows maps creation - iteration  965  of  983
# Flows maps creation - iteration  966  of  983
# Flows maps creation - iteration  967  of  983
# Flows maps creation - iteration  968  of  983
# Flows maps creation - iteration  969  of  983
# Flows maps creation - iteration  970  of  983
# Flows maps creation - iteration  971  of  983
# Flows maps creation - iteration  972  of  983
# Flows maps creation - iteration  973  of  983
# Flows maps creation - iteration  974  of  983
# Flows maps creation - iteration  975  of  983
# Flows maps creation - iteration  976  of  983
# Flows maps creation - iteration  977  of  983
# Flows maps creation - iteration  978  of  983
# Flows maps creation - iteration  979  of  983
# Flows maps creation - iteration  980  of  983
# Flows maps creation - iteration  981  of  983
# Flows maps creation - iteration  982  of  983
# Flows maps creation - iteration  983  of  983

# %%
ox.save_graph_geopackage(X1, filepath='Flows1.gpkg')
